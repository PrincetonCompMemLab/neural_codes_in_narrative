# %%
import numpy as np
import os

dir = "/scratch/gpfs/rk1593/clustering_output/"
X_list = []
searchlight_list = []
for index,file in enumerate(os.scandir(dir + "searchlights_collapseTR/")):
    file_name = file.name
    if ".csv" in file_name:
        if file_name == "64_30_33.csv":
            print("skipped 64_30_33.csv")
            continue
        if "NOT480" in file_name:
            print("Error: NOT480 ", file_name)
        if index % 10000 == 0:
            print(index)
        light_id = file_name.split(".")[0]
        features = np.genfromtxt(dir + "searchlights_collapseTR/" + file_name, delimiter = ",").tolist()
        searchlight_list += [light_id]
        X_list += [features]

print("extracted for /searchlights/ directory")
X = np.vstack(X_list)
print(X.shape)
np.save(file = dir + "kmeans_assignments_tval_collapseTR/master_X_list_collapseTR.npy", arr = X)
np.save(file = dir + "kmeans_assignments_tval_collapseTR/master_searchlight_collapseTR.npy", arr = np.array(searchlight_list))
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# skipped 64_30_33.csv
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# extracted for /searchlights/ directory
# (185404, 54)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-84f30fcca889> in <module>
#      23 X = np.vstack(X_list)
#      24 print(X.shape)
# ---> 25 np.save(file = dir + "kmeans_assignments_tval_collapseTR_confirm/master_X_list_collapseTR.npy", arr = X)
#      26 np.save(file = dir + "kmeans_assignments_tval_collapseTR_confirm/master_searchlight_collapseTR.npy", arr = np.array(searchlight_list))
#      27
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~/.conda/envs/wedding_schema/lib/python3.8/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     523         if not file.endswith('.npy'):
#     524             file = file + '.npy'
# --> 525         file_ctx = open(file, "wb")
#     526
#     527     with file_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch/gpfs/rk1593/clustering_output/kmeans_assignments_tval_collapseTR_confirm/master_X_list_collapseTR.npy'

# %%
np.save(file = dir + "kmeans_assignments_tval_collapseTR/master_X_list_collapseTR.npy", arr = X)
np.save(file = dir + "kmeans_assignments_tval_collapseTR/master_searchlight_collapseTR.npy", arr = np.array(searchlight_list))

# %%
dir
# Out:
# '/scratch/gpfs/rk1593/clustering_output/'

# %%
len(searchlight_list)
# Out:
# 185404

# %%
import pickle
import pandas as pd
import numpy as np
import os
from sklearn.cluster import KMeans


def kmeans_clustering(dir, K):
    # read in the master_X_list and master_searchlight so that we have the cluster assignments
    # for the searchlights without having to output so much data each time
    # by outputting the master_X_list to the output csv multiple times
    # which would be a waste of della's memory
    X = np.load(file = dir + "master_X_list_collapseTR.npy")
    searchlight_list = np.load(file = dir + "master_searchlight_collapseTR.npy").tolist()
    print("K_clusters: ", K)
    kmeans = KMeans(n_clusters=K)
    cluster_labels = kmeans.fit_predict(X)
    # add 1 so that we have no label with zero
    cluster_labels += 1
    # create csv with the cluster assignment for this number of clusters
    # create the output df by giving cluster labels
    this_cost = kmeans.inertia_
    cost_list = [this_cost for i in range(len(searchlight_list))]
    output_dict = {"cluster_assignment": cluster_labels.tolist(),
                "searchlight": searchlight_list,
                "cost":cost_list
                }
    df = pd.DataFrame(output_dict)
    df.to_csv(dir + "kmeans_" + str(K) + "clusters_collapseTR.csv")
    # It is important to use binary access
    with open(dir + "kmeans_" + str(K) + "clusters_collapseTR.pickle", 'wb') as f:
        pickle.dump(kmeans, f)
  
for job_id_in in range(4,11):
    #job_id_in = 4#int(os.environ["SLURM_ARRAY_TASK_ID"])
    dir = "/scratch/gpfs/rk1593/clustering_output/kmeans_assignments_tval_collapseTR/"
    K = job_id_in
    kmeans_clustering(dir = dir, K = K)
# Out:
# K_clusters:  4
# K_clusters:  5
# K_clusters:  6
# K_clusters:  7
# K_clusters:  8
# K_clusters:  9
# K_clusters:  10

# %%
    dir = "/scratch/gpfs/rk1593/clustering_output/kmeans_assignments_tval/"
X = np.load(file = dir + "master_X_list_tval.npy")
X.shape
# Out:
# (185405, 774)

# %%
import numpy as np
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_samples
import os
import pandas as pd

num_jobs = 4
dir = "/scratch/gpfs/rk1593/clustering_output/" 
#job_id_in = int(os.environ["SLURM_ARRAY_TASK_ID"])
for job_id_in in [2,3]:
    K = job_id_in
    labels_dir = "/scratch/gpfs/rk1593/clustering_output/kmeans_assignments_collapseTR/kmeans_" + str(K) + "clusters_collapseTR.csv"
    df = pd.read_csv(labels_dir)
    labels = df["cluster_assignment"].tolist()
    df = 0 # for memory
    output_dir = "/scratch/gpfs/rk1593/clustering_output/kmeans_silhouette_collapseTR/kmeans" + str(K) + "_silhouttes_collapseTR.csv"
    X = np.load("/scratch/gpfs/rk1593/clustering_output/kmeans_assignments_collapseTR/master_X_list_collapseTR.npy")
    X = X.astype("float32") # for memory limits
    print("got X")
    D_matrix = pairwise_distances(X, n_jobs= num_jobs)
    print("got D_matrix")
    X = 0
    sample_silhouette_values = silhouette_samples(X = D_matrix, labels = labels, metric = 'precomputed')
    print("got s_coeffs")
    np.savetxt(output_dir, sample_silhouette_values, delimiter=",")
# Out:
# got X
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ad66e6f32986> in <module>
#      18     X = X.astype("float32") # for memory limits
#      19     print("got X")
# ---> 20     D_matrix = pairwise_distances(X, n_jobs= num_jobs)
#      21     print("got D_matrix")
#      22     X = 0
#
# ~/.conda/envs/wedding_schema/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.conda/envs/wedding_schema/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1777         func = partial(distance.cdist, metric=metric, **kwds)
#    1778
# -> 1779     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1780
#    1781
#
# ~/.conda/envs/wedding_schema/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1363     fd = delayed(_dist_wrapper)
#    1364     ret = np.empty((X.shape[0], Y.shape[0]), dtype=dtype, order='F')
# -> 1365     Parallel(backend="threading", n_jobs=n_jobs)(
#    1366         fd(func, ret, s, X, Y[s], **kwds)
#    1367         for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs)))
#
# ~/.conda/envs/wedding_schema/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/.conda/envs/wedding_schema/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/.conda/envs/wedding_schema/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/.conda/envs/wedding_schema/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/.conda/envs/wedding_schema/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/.conda/envs/wedding_schema/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
