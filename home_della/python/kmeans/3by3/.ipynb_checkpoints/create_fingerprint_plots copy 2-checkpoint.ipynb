# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import random
import msgpack
from statistics import stdev
import math
import pdb

# %%
all_comparison_differences6 = ['sameEv-sameSchema_sameEv-otherSchema',
                        'sameEv-sameSchema_otherEv-sameSchema',
                        'sameEv-sameSchema_otherEv-otherSchema',
                        'sameEv-otherSchema_otherEv-sameSchema',
                        'sameEv-otherSchema_otherEv-otherSchema',
                        'otherEv-sameSchema_otherEv-otherSchema']
comparison_groups4 = ['sameEv-sameSchema', 'sameEv-otherSchema', 'otherEv-sameSchema', 'otherEv-otherSchema']
palette= [ "mediumorchid","royalblue", "yellow", "tomato"]
palette_labels = ["purple", "blue", "yellow", "red"]
all6_differences_labels = []
for comparison_name in all_comparison_differences6:
    compare1_name,compare2_name = comparison_name.split("_")
    all6_differences_labels.append(palette_labels[comparison_groups4.index(compare1_name)] + " - " + palette_labels[comparison_groups4.index(compare2_name)])


event_1_start = 17
event_2_start = 23
event_3_start = 34
event_4_start = 50
event_5_start = 66
# best searchlights in cluster 1, schema code for K = 5:
# 0,0.24304065108299255,38_68_74
# 1,0.23760776221752167,39_68_74
# 2,0.2372482717037201,37_68_74
# 3,0.2359982430934906,38_71_73
# 4,0.23568299412727356,36_68_74
# 5,0.23505918681621552,38_70_73
# 6,0.2350563257932663,38_69_74
# 7,0.2345806360244751,37_70_73
# 8,0.23427341878414154,38_72_72
K5_cluster1_best = "38_72_72"

# %%
# get 12 by 74 matrices with 36 comparisons for this searchlight (info for RSA plot now comparing at each TR for each held-out wedding)
def get_template_to_pid_to_cond_to_matrix(light_id, in_dir = "/scratch/gpfs/rk1593/clustering_output/"):
    template_to_pid_to_cond_to_matrices = {}
    with open(in_dir + "searchlights_matrices_msgpack/" + light_id, "rb") as json_file:
        template_to_pid_to_cond_to_matrices = msgpack.load(json_file, strict_map_key = False) 
    return template_to_pid_to_cond_to_matrices
template_to_pid_to_cond_to_matrix = get_template_to_pid_to_cond_to_matrix(K5_cluster1_best)

# %%
# get tr differences each participant (time series of 6 lines)
def template_to_pid_to_cond_to_matrix_to_differences(template_to_pid_to_cond_to_matrix):
    template_to_compare_to_pid_to_tr_diffs = {}
    for template_id in template_to_pid_to_cond_to_matrix:
        if template_id not in template_to_compare_to_pid_to_tr_diffs:
            template_to_compare_to_pid_to_tr_diffs[template_id] = {}
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            for comparison_name in all_comparison_differences6:
                compare1_name,compare2_name = comparison_name.split("_")    
                if comparison_name not in template_to_compare_to_pid_to_tr_diffs[template_id]:
                    template_to_compare_to_pid_to_tr_diffs[template_id][comparison_name] = {}
                compare1_matrix =  template_to_pid_to_cond_to_matrix[template_id][pid][compare1_name]
                compare1_list = np.nanmean(compare1_matrix, axis = 0).tolist()
                compare2_matrix = template_to_pid_to_cond_to_matrix[template_id][pid][compare2_name]
                compare2_list = np.nanmean(compare2_matrix, axis = 0).tolist()

                if len(compare1_list) != len(compare2_list):
                    print("Error: for the same template and light, two paths have different number of tr's")
                    return
                tr_differences = [(compare1_list[i] - compare2_list[i]) for i in range(len(compare1_list))]
                tr_differences = tr_differences
                template_to_compare_to_pid_to_tr_diffs[template_id][comparison_name][pid] = tr_differences
    return template_to_compare_to_pid_to_tr_diffs
template_to_compare_to_pid_to_tr_diffs = template_to_pid_to_cond_to_matrix_to_differences(template_to_pid_to_cond_to_matrix)
template_to_compare_to_pid_to_tr_diffs[2]
# Out:
# {'sameEv-sameSchema_sameEv-otherSchema': {'sub-129': [-0.11750000000000003,
#    -0.1475,
#    -0.135,
#    -0.15416666666666665,
#    -0.1225,
#    -0.135,
#    -0.14833333333333334,
#    -0.14833333333333332,
#    -0.115,
#    -0.12583333333333335,
#    -0.11583333333333333,
#    -0.11333333333333334,
#    -0.06249999999999999,
#    -0.06583333333333333,
#    -0.07666666666666666,
#    -0.10750000000000001,
#    -0.10333333333333335,
#    -0.0625,
#    -0.0875,
#    -0.06416666666666666,
#    -0.16333333333333333,
#    -0.06583333333333334,
#    -0.12,
#    -0.0875,
#    -0.14666666666666667,
#    -0.15083333333333332,
#    -0.15833333333333333,
#    -0.1175,
#    -0.06166666666666666,
#    -0.08916666666666667,
#    -0.1,
#    -0.13499999999999998,
#    -0.09333333333333332,
#    -0.12833333333333333,
#    -0.15000000000000002,
#    -0.06583333333333333,
#    -0.10333333333333333,
#    -0.07750000000000001,
#    0.008333333333333342,
#    -0.010000000000000005,
#    -0.0008333333333333266,
#    -0.07916666666666666,
#    -0.03416666666666668,
#    -0.022499999999999996,
#    -0.07333333333333333,
#    -0.042499999999999996,
#    -0.0975,
#    -0.06416666666666666,
#    -0.01583333333333333,
#    -0.0875,
#    -0.0625,
#    -0.07583333333333332,
#    -0.11166666666666669,
#    -0.07166666666666667,
#    0.010833333333333344,
#    0.0008333333333333318,
#    -0.007499999999999993,
#    0.05916666666666666,
#    0.006666666666666677,
#    0.04583333333333334,
#    0.045833333333333344,
#    0.08999999999999997,
#    -0.005833333333333336,
#    0.024166666666666666,
#    0.030833333333333327,
#    0.04999999999999999,
#    0.14083333333333334,
#    -0.006666666666666654,
#    0.11499999999999999,
#    0.06333333333333335,
#    0.035833333333333335,
#    0.12666666666666665,
#    0.05500000000000001,
#    0.085],
#   'sub-110': [-0.025833333333333333,
#    -0.0175,
#    0.06666666666666667,
#    0.061666666666666675,
#    0.04416666666666667,
#    0.019999999999999983,
#    0.01583333333333334,
#    -0.0024999999999999988,
#    0.06666666666666668,
#    0.038333333333333344,
#    -0.022500000000000003,
#    -0.0016666666666666588,
#    0.15250000000000002,
#    0.26999999999999996,
#    0.06416666666666666,
#    0.053333333333333344,
#    0.04166666666666668,
#    0.0716666666666667,
#    0.07249999999999998,
#    -0.03916666666666667,
#    0.00666666666666667,
#    -0.024166666666666673,
#    0.02,
#    0.07333333333333333,
#    0.03583333333333333,
#    0.08083333333333331,
#    0.15583333333333335,
#    0.15416666666666667,
#    0.1416666666666667,
#    -0.008333333333333331,
#    -0.08833333333333332,
#    0.07583333333333332,
#    0.04083333333333333,
#    0.10666666666666669,
#    0.10083333333333336,
#    0.165,
#    0.15083333333333335,
#    0.21083333333333334,
#    0.10250000000000001,
#    -0.0008333333333333248,
#    -0.030000000000000002,
#    0.05000000000000001,
#    -0.027499999999999983,
#    0.11500000000000002,
#    0.08250000000000002,
#    0.22166666666666668,
#    0.1425,
#    -0.0475,
#    0.04083333333333333,
#    0.007500000000000007,
#    0.0066666666666666645,
#    0.053333333333333344,
#    0.15833333333333335,
#    0.04583333333333333,
#    0.125,
#    0.09833333333333334,
#    0.056666666666666664,
#    -0.008333333333333318,
#    0.22166666666666668,
#    0.09166666666666667,
#    0.12000000000000001,
#    0.028333333333333342,
#    0.016666666666666663,
#    -0.003333333333333334,
#    0.020833333333333336,
#    0.10583333333333333,
#    0.14583333333333331,
#    0.2475,
#    0.1575,
#    0.15916666666666668,
#    0.06333333333333332,
#    0.04916666666666668,
#    0.09999999999999999,
#    -0.06083333333333333],
#   'sub-123': [0.17833333333333334,
#    0.05916666666666667,
#    0.06833333333333333,
#    -0.005833333333333343,
#    0.04416666666666666,
#    0.045,
#    0.07583333333333334,
#    0.0775,
#    0.06583333333333334,
#    0.010833333333333328,
#    0.056666666666666664,
#    0.055833333333333346,
#    0.085,
#    0.0225,
#    0.12583333333333332,
#    0.08083333333333331,
#    0.07583333333333334,
#    0.02416666666666669,
#    -0.05916666666666667,
#    0.05416666666666666,
#    -0.00416666666666668,
#    0.027500000000000004,
#    0.02166666666666666,
#    0.11166666666666666,
#    0.04916666666666666,
#    0.16333333333333333,
#    0.09333333333333334,
#    0.030833333333333324,
#    -0.06583333333333334,
#    -0.045000000000000005,
#    0.0008333333333333456,
#    0.035833333333333335,
#    0.04833333333333334,
#    0.085,
#    0.07083333333333333,
#    0.051666666666666666,
#    0.12916666666666668,
#    0.06583333333333331,
#    0.01249999999999999,
#    -0.05166666666666667,
#    -0.04083333333333333,
#    -0.0008333333333333318,
#    -0.029166666666666674,
#    0.028333333333333335,
#    -0.008333333333333328,
#    0.014166666666666682,
#    0.004999999999999994,
#    0.020833333333333332,
#    -0.049166666666666664,
#    0.11666666666666665,
#    0.06250000000000001,
#    0.014166666666666675,
#    0.021666666666666674,
#    0.03416666666666668,
#    0.10166666666666668,
#    0.07583333333333334,
#    0.026666666666666665,
#    0.08249999999999999,
#    0.04999999999999999,
#    0.15500000000000005,
#    0.135,
#    0.08499999999999999,
#    0.16749999999999998,
#    0.06166666666666668,
#    0.11166666666666666,
#    -0.05666666666666667,
#    0.011666666666666652,
#    0.09499999999999999,
#    -0.012499999999999976,
#    0.07666666666666665,
#    0.10083333333333334,
#    -0.0049999999999999906,
#    0.05666666666666667,
#    -0.1466666666666667],
#   'sub-140': [-0.08583333333333334,
#    -0.05916666666666669,
#    0.010833333333333337,
#    -0.03416666666666667,
#    -0.07083333333333335,
#    -0.020833333333333332,
#    -0.0033333333333333288,
#    -0.07416666666666667,
#    -0.049166666666666664,
#    -0.01583333333333334,
#    1.3877787807814457e-17,
#    -0.05916666666666666,
#    -0.09666666666666664,
#    -0.02749999999999999,
#    0.00083333333333333,
#    -0.011666666666666665,
#    -0.04250000000000001,
#    -0.11499999999999999,
#    -0.03000000000000001,
#    -0.02083333333333333,
#    0.08333333333333334,
#    0.034166666666666665,
#    0.13416666666666666,
#    0.048333333333333346,
#    0.016666666666666677,
#    -0.015833333333333338,
#    -0.017499999999999995,
#    -0.027500000000000007,
#    -0.025833333333333326,
#    0.01833333333333332,
#    -0.05833333333333332,
#    -0.04916666666666667,
#    -0.03000000000000001,
#    -0.014166666666666664,
#    0.0008333333333333387,
#    0.05083333333333333,
#    0.014166666666666668,
#    0.005833333333333343,
#    0.034166666666666665,
#    -0.04166666666666668,
#    -0.0016666666666666637,
#    0.004166666666666666,
#    0.023333333333333352,
#    0.03416666666666666,
#    0.017499999999999998,
#    -0.005833333333333332,
#    0.03666666666666668,
#    0.018333333333333337,
#    -0.024166666666666677,
#    -0.09916666666666665,
#    0.017499999999999995,
#    -0.10083333333333334,
#    -0.04666666666666666,
#    -0.046666666666666676,
#    0.01083333333333334,
#    0.008333333333333321,
#    0.003333333333333341,
#    0.03833333333333334,
#    -0.013333333333333332,
#    0.025833333333333326,
#    0.011666666666666665,
#    0.007499999999999993,
#    -0.02250000000000001,
#    0.10916666666666666,
#    0.036666666666666695,
#    0.015000000000000013,
#    0.07916666666666666,
#    0.10999999999999999,
#    0.09333333333333332,
#    -0.008333333333333331,
#    0.07166666666666667,
#    0.0475,
#    0.053333333333333344,
#    0.02666666666666666],
#   'sub-135': [-0.024166666666666663,
#    -0.135,
#    0.01916666666666668,
#    0.013333333333333329,
#    -0.045000000000000005,
#    0.04083333333333333,
#    -0.0008333333333333248,
#    0.11166666666666664,
#    0.007499999999999996,
#    0.09416666666666668,
#    0.02916666666666666,
#    -0.06333333333333332,
#    -0.05916666666666666,
#    0.006666666666666689,
#    0.013333333333333322,
#    -0.010000000000000009,
#    -0.020000000000000004,
#    -0.08750000000000001,
#    -0.08666666666666667,
#    -0.09583333333333333,
#    -0.09833333333333333,
#    -0.08000000000000002,
#    -0.010000000000000002,
#    -0.09416666666666669,
#    0.009999999999999988,
#    -0.11750000000000001,
#    -0.044166666666666674,
#    -0.020000000000000004,
#    -0.02583333333333334,
#    -0.09499999999999999,
#    -0.12083333333333335,
#    -0.0075,
#    -0.06583333333333333,
#    0.011666666666666676,
#    0.030833333333333317,
#    -0.1391666666666667,
#    -0.04083333333333334,
#    0.07750000000000003,
#    -0.020833333333333332,
#    0.07666666666666667,
#    0.10999999999999999,
#    0.08666666666666667,
#    0.06416666666666666,
#    -0.034999999999999996,
#    -0.0074999999999999945,
#    0.05499999999999999,
#    0.08583333333333333,
#    0.021666666666666674,
#    -0.07916666666666666,
#    -0.04916666666666665,
#    0.095,
#    0.07083333333333333,
#    0.06666666666666665,
#    0.105,
#    -0.03749999999999999,
#    0.025000000000000012,
#    -0.055833333333333325,
#    0.04916666666666665,
#    0.028333333333333332,
#    0.050833333333333335,
#    0.006666666666666661,
#    0.055,
#    0.019166666666666676,
#    0.11083333333333334,
#    0.08583333333333333,
#    0.11166666666666668,
#    -0.019999999999999993,
#    -0.01249999999999999,
#    -0.006666666666666668,
#    0.04083333333333334,
#    -0.09416666666666666,
#    0.075,
#    0.03,
#    0.049166666666666664],
#   'sub-127': [0.39083333333333337,
#    0.5208333333333333,
#    0.5341666666666667,
#    0.6466666666666667,
#    0.5425,
#    0.6491666666666666,
#    0.6891666666666667,
#    0.68,
#    0.7333333333333334,
#    0.7816666666666668,
#    0.6733333333333333,
#    0.6,
#    0.855,
#    0.6766666666666666,
#    0.7391666666666667,
#    0.69,
#    0.7558333333333331,
#    0.7783333333333333,
#    0.71,
#    0.7716666666666667,
#    0.8424999999999999,
#    0.81,
#    0.6400000000000001,
#    0.8558333333333333,
#    0.8058333333333334,
#    0.6841666666666666,
#    0.7766666666666666,
#    0.6391666666666667,
#    0.73,
#    0.7741666666666667,
#    0.6633333333333333,
#    0.8175000000000001,
#    0.6058333333333332,
#    0.6283333333333334,
#    0.6074999999999999,
#    0.61,
#    0.47916666666666674,
#    0.35833333333333334,
#    0.5133333333333334,
#    0.6316666666666666,
#    0.5816666666666668,
#    0.7291666666666667,
#    0.6941666666666666,
#    0.575,
#    0.5725,
#    0.5608333333333333,
#    0.5808333333333333,
#    0.5333333333333333,
#    0.4958333333333334,
#    0.6000000000000001,
#    0.4225,
#    0.45666666666666667,
#    0.4108333333333334,
#    0.5208333333333334,
#    0.4966666666666666,
#    0.3908333333333333,
#    0.48250000000000004,
#    0.48250000000000004,
#    0.5333333333333334,
#    0.455,
#    0.32999999999999996,
#    0.42833333333333345,
#    0.44583333333333336,
#    0.46333333333333326,
#    0.5391666666666666,
#    0.5608333333333333,
#    0.5916666666666668,
#    0.5766666666666667,
#    0.46916666666666673,
#    0.37749999999999995,
#    0.51,
#    0.42666666666666664,
#    0.375,
#    0.4316666666666667],
#   'sub-136': [0.10250000000000001,
#    0.10999999999999999,
#    -0.009166666666666662,
#    0.023333333333333338,
#    0.0975,
#    0.10166666666666666,
#    0.08416666666666667,
#    -0.055833333333333325,
#    -0.07833333333333334,
#    -0.06249999999999999,
#    0.029166666666666674,
#    0.09916666666666665,
#    0.08916666666666669,
#    -0.009166666666666656,
#    0.0008333333333333387,
#    0.04166666666666665,
#    0.029999999999999995,
#    -0.060000000000000005,
#    -0.06666666666666665,
#    -0.003333333333333353,
#    -0.03833333333333336,
#    -0.011666666666666665,
#    -0.015833333333333328,
#    -0.05250000000000002,
#    0.00583333333333334,
#    -0.0033333333333333305,
#    -0.023333333333333352,
#    0.015833333333333324,
#    0.014166666666666654,
#    -0.013333333333333336,
#    0.0016666666666666774,
#    -0.09916666666666668,
#    0.0333333333333333,
#    0.003333333333333335,
#    -0.014166666666666668,
#    0.004166666666666666,
#    0.024166666666666677,
#    -0.034166666666666665,
#    1.0408340855860843e-17,
#    0.030833333333333327,
#    -0.04166666666666667,
#    0.015833333333333328,
#    -0.004999999999999997,
#    -0.10750000000000001,
#    -0.06999999999999999,
#    -0.014166666666666668,
#    0.02083333333333333,
#    0.010000000000000005,
#    -0.08916666666666666,
#    0.04916666666666667,
#    0.05583333333333334,
#    0.049166666666666664,
#    -0.05666666666666667,
#    0.017499999999999988,
#    -0.03833333333333336,
#    0.0841666666666667,
#    0.02166666666666668,
#    -0.007499999999999993,
#    -0.03583333333333334,
#    -0.06833333333333334,
#    -0.01,
#    -0.027500000000000004,
#    0.02416666666666667,
#    -0.04000000000000001,
#    -0.0675,
#    -0.034166666666666665,
#    -0.06333333333333332,
#    0.04833333333333334,
#    0.03166666666666666,
#    -0.01583333333333333,
#    -0.0050000000000000044,
#    -0.05166666666666667,
#    -0.04250000000000002,
#    -0.07833333333333335],
#   'sub-107': [0.08833333333333335,
#    0.016666666666666666,
#    -0.01833333333333334,
#    0.023333333333333327,
#    0.05833333333333336,
#    0.05500000000000001,
#    0.0825,
#    0.017500000000000005,
#    0.044166666666666674,
#    0.02999999999999999,
#    0.009166666666666656,
#    -0.09000000000000001,
#    -0.009999999999999995,
#    -0.045,
#    0.00416666666666668,
#    -0.027500000000000004,
#    0.021666666666666654,
#    0.01416666666666666,
#    0.07166666666666668,
#    -0.05416666666666666,
#    -0.008333333333333338,
#    -0.005833333333333348,
#    -0.0825,
#    -0.03083333333333333,
#    0.018333333333333333,
#    0.0050000000000000044,
#    -0.013333333333333315,
#    0.02416666666666667,
#    0.062499999999999986,
#    0.044999999999999984,
#    -0.013333333333333346,
#    -0.03333333333333332,
#    0.005000000000000018,
#    0.07666666666666666,
#    0.08333333333333334,
#    0.07583333333333335,
#    0.04750000000000001,
#    0.057499999999999996,
#    0.06000000000000001,
#    0.07333333333333333,
#    0.10166666666666668,
#    0.1466666666666667,
#    0.04999999999999999,
#    0.04833333333333333,
#    0.026666666666666658,
#    0.07333333333333333,
#    0.1241666666666667,
#    0.05666666666666667,
#    0.10833333333333334,
#    0.13083333333333336,
#    0.1275,
#    0.11499999999999999,
#    0.05749999999999998,
#    0.04083333333333332,
#    0.10833333333333335,
#    0.09666666666666662,
#    0.09666666666666668,
#    0.09333333333333335,
#    -0.020833333333333343,
#    0.05916666666666667,
#    0.04416666666666667,
#    0.18833333333333335,
#    0.11499999999999999,
#    0.08833333333333333,
#    0.12583333333333332,
#    0.003333333333333334,
#    0.09166666666666666,
#    0.1108333333333333,
#    0.13583333333333333,
#    0.07083333333333336,
#    0.06666666666666668,
#    0.03083333333333333,
#    0.011666666666666662,
#    0.085],
#   'sub-112': [0.060833333333333336,
#    -0.07666666666666667,
#    0.03083333333333333,
#    0.08583333333333334,
#    -0.003333333333333334,
#    0.05666666666666668,
#    0.09250000000000001,
#    0.06666666666666668,
#    0.021666666666666667,
#    0.007500000000000003,
#    0.13083333333333333,
#    -0.01833333333333333,
#    0.016666666666666673,
#    0.08499999999999999,
#    -0.03250000000000001,
#    0.0225,
#    0.024166666666666656,
#    -0.11833333333333333,
#    -0.04750000000000001,
#    -0.09666666666666668,
#    -0.08750000000000001,
#    -0.026666666666666672,
#    0.0025000000000000014,
#    -0.0075,
#    -0.08166666666666667,
#    -0.0050000000000000044,
#    -0.028333333333333332,
#    0.057499999999999996,
#    0.13833333333333334,
#    0.059999999999999984,
#    0.04583333333333334,
#    0.10750000000000001,
#    -0.008333333333333349,
#    0.045,
#    0.06250000000000001,
#    0.006666666666666675,
#    0.005833333333333337,
#    -0.05583333333333333,
#    -0.10166666666666667,
#    -0.02999999999999999,
#    0.022499999999999996,
#    0.02333333333333333,
#    0.006666666666666676,
#    0.07333333333333333,
#    0.09916666666666665,
#    0.04166666666666667,
#    0.1,
#    0.16249999999999998,
#    0.09666666666666669,
#    0.11583333333333332,
#    -0.05666666666666667,
#    0.0066666666666666706,
#    0.08083333333333334,
#    0.0725,
#    -0.005833333333333338,
#    -0.03416666666666668,
#    0.014999999999999993,
#    0.10666666666666667,
#    0.14916666666666664,
#    0.08333333333333333,
#    0.14833333333333337,
#    -0.012500000000000011,
#    0.05416666666666667,
#    -0.009999999999999981,
#    0.03916666666666667,
#    -0.0050000000000000044,
#    -0.004999999999999984,
#    -0.05749999999999997,
#    -0.08500000000000002,
#    -0.05416666666666667,
#    -0.04583333333333333,
#    0.06333333333333332,
#    0.10250000000000001,
#    -0.065],
#   'sub-138': [0.0008333333333333283,
#    -0.029166666666666667,
#    0.009999999999999998,
#    0.0016666666666666791,
#    -0.020000000000000007,
#    -0.03666666666666665,
#    -0.025,
#    0.037500000000000006,
#    0.05916666666666666,
#    0.056666666666666685,
#    -0.022500000000000003,
#    -0.03166666666666666,
#    -0.02666666666666665,
#    0.03750000000000002,
#    -0.019166666666666658,
#    -0.02666666666666667,
#    -0.013333333333333329,
#    0.00916666666666667,
#    -0.06249999999999999,
#    0.0125,
#    -0.10666666666666666,
#    -0.07666666666666666,
#    -0.050833333333333335,
#    0.00083333333333333,
#    -0.012500000000000004,
#    -0.11916666666666667,
#    -0.11499999999999999,
#    -0.06416666666666668,
#    -0.05583333333333333,
#    0.008333333333333331,
#    -0.14500000000000002,
#    -0.06750000000000002,
#    -0.11666666666666668,
#    -0.06749999999999998,
#    -0.0049999999999999906,
#    -0.09666666666666668,
#    -0.12166666666666667,
#    -0.01,
#    -0.06833333333333333,
#    0.003333333333333334,
#    -0.10833333333333332,
#    -0.07250000000000004,
#    0.045,
#    0.1275,
#    0.01833333333333333,
#    -0.065,
#    -0.005833333333333333,
#    -0.016666666666666666,
#    -0.07083333333333332,
#    0.038333333333333344,
#    0.0575,
#    0.049999999999999996,
#    0.013333333333333332,
#    0.0,
#    0.058333333333333334,
#    -0.061666666666666675,
#    0.023333333333333338,
#    0.013333333333333336,
#    -0.0325,
#    0.05083333333333333,
#    0.0025000000000000022,
#    0.024166666666666663,
#    0.01916666666666667,
#    0.039999999999999994,
#    0.05499999999999999,
#    0.034166666666666665,
#    0.06916666666666667,
#    0.04916666666666667,
#    0.03333333333333333,
#    0.018333333333333347,
#    0.04333333333333333,
#    0.03750000000000001,
#    0.0775,
#    0.06000000000000001],
#   'sub-134': [0.015,
#    -0.014166666666666657,
#    0.10833333333333334,
#    -0.01833333333333334,
#    0.03250000000000001,
#    0.04166666666666666,
#    0.00750000000000001,
#    0.010833333333333344,
#    0.06083333333333334,
#    0.06833333333333334,
#    0.08583333333333333,
#    0.07333333333333333,
#    -0.013333333333333326,
#    0.07750000000000001,
#    0.011666666666666662,
#    0.05916666666666669,
#    0.03666666666666666,
#    -0.0008333333333333179,
#    -0.014166666666666668,
#    0.03333333333333334,
#    0.1,
#    0.05083333333333333,
#    0.0675,
#    0.03166666666666668,
#    0.004166666666666659,
#    0.085,
#    0.0,
#    0.045,
#    -0.005000000000000003,
#    -0.03416666666666667,
#    -0.017499999999999988,
#    -0.05916666666666666,
#    -0.008333333333333335,
#    -0.017499999999999995,
#    -0.058333333333333334,
#    0.025833333333333333,
#    0.040833333333333346,
#    0.00333333333333332,
#    0.03499999999999999,
#    0.05666666666666667,
#    0.03749999999999999,
#    0.045,
#    0.0024999999999999953,
#    0.062499999999999986,
#    1.3877787807814457e-17,
#    -0.02749999999999997,
#    0.06749999999999999,
#    0.045833333333333344,
#    0.07833333333333334,
#    0.09250000000000003,
#    -0.00083333333333333,
#    0.039999999999999994,
#    0.07916666666666666,
#    0.13333333333333336,
#    0.11249999999999999,
#    0.039999999999999994,
#    0.08166666666666668,
#    0.027500000000000004,
#    0.06,
#    -0.0049999999999999906,
#    0.07416666666666667,
#    0.04166666666666664,
#    -0.003333333333333327,
#    0.03000000000000001,
#    0.02833333333333333,
#    -0.00916666666666667,
#    0.025000000000000015,
#    -0.0325,
#    -0.07583333333333334,
#    0.020833333333333336,
#    0.014999999999999996,
#    0.04083333333333333,
#    0.027500000000000004,
#    -0.08999999999999998],
#   'sub-115': [0.0625,
#    -0.025,
#    0.012500000000000002,
#    0.014166666666666671,
#    -0.03833333333333334,
#    -0.056666666666666664,
#    -0.010833333333333344,
#    -0.04916666666666668,
#    -0.051666666666666694,
#    -0.06166666666666666,
#    -0.005833333333333315,
#    -0.07916666666666665,
#    0.039999999999999994,
#    -0.07333333333333335,
#    0.07666666666666667,
#    0.06833333333333333,
#    -0.027500000000000004,
#    0.03333333333333334,
#    0.03749999999999999,
#    0.015833333333333328,
#    0.027499999999999997,
#    -0.01583333333333333,
#    -0.03666666666666665,
#    -0.14,
#    -0.03166666666666666,
#    0.0033333333333333227,
#    -0.04249999999999998,
#    0.06416666666666668,
#    -0.1325,
#    -0.034166666666666665,
#    -0.020833333333333325,
#    -0.06666666666666665,
#    0.010000000000000009,
#    -0.04583333333333333,
#    -0.07666666666666665,
#    -0.10083333333333332,
#    0.04583333333333335,
#    0.07333333333333333,
#    0.060833333333333336,
#    0.02916666666666668,
#    -0.035,
#    -0.05999999999999998,
#    -0.050833333333333314,
#    -0.0016666666666666496,
#    0.05,
#    0.033333333333333326,
#    -0.06916666666666668,
#    -0.08,
#    -0.06833333333333334,
#    -0.014166666666666682,
#    -0.08749999999999998,
#    -0.03749999999999999,
#    0.055,
#    0.004166666666666666,
#    -0.025833333333333333,
#    -0.09166666666666666,
#    -0.10499999999999998,
#    -0.0725,
#    -0.11750000000000002,
#    -0.031666666666666655,
#    -0.085,
#    -0.0325,
#    -0.10666666666666667,
#    -0.04916666666666666,
#    -0.06583333333333334,
#    -0.023333333333333334,
#    -0.11166666666666668,
#    -0.11083333333333333,
#    -0.1275,
#    -0.03916666666666667,
#    -0.13166666666666668,
#    -0.056666666666666685,
#    -0.07,
#    -0.08499999999999999],
#   'sub-131': [-0.03,
#    0.008333333333333349,
#    0.085,
#    -0.044166666666666674,
#    0.03833333333333334,
#    0.09416666666666668,
#    0.05833333333333335,
#    0.13583333333333333,
#    0.1325,
#    -0.05499999999999999,
#    0.044166666666666674,
#    0.09333333333333332,
#    0.06916666666666665,
#    0.06833333333333336,
#    -0.04666666666666669,
#    0.04916666666666667,
#    0.02083333333333335,
#    -0.014999999999999998,
#    0.08916666666666666,
#    -0.005833333333333322,
#    -0.013333333333333329,
#    -0.12083333333333335,
#    -0.10416666666666666,
#    -0.014166666666666702,
#    -0.04583333333333331,
#    0.07333333333333333,
#    -0.03249999999999997,
#    -0.22416666666666665,
#    -0.025833333333333333,
#    -0.19583333333333333,
#    -0.10833333333333331,
#    -0.1216666666666667,
#    0.07583333333333335,
#    -0.2,
#    0.0024999999999999745,
#    -0.045833333333333344,
#    -0.021666666666666647,
#    -0.04916666666666666,
#    0.20500000000000007,
#    0.038333333333333316,
#    0.09416666666666665,
#    -0.005833333333333334,
#    -0.051666666666666666,
#    -0.09166666666666667,
#    -0.0866666666666667,
#    -0.035,
#    0.1425,
#    -0.014166666666666668,
#    0.06833333333333336,
#    -0.07416666666666669,
#    -0.03833333333333336,
#    -0.0725,
#    0.016666666666666653,
#    -0.02166666666666667,
#    -0.018333333333333326,
#    0.05083333333333335,
#    0.22250000000000003,
#    0.1275,
#    0.0525,
#    -0.019166666666666683,
#    -0.04666666666666668,
#    -0.053333333333333316,
#    0.010833333333333334,
#    -0.16,
#    0.1341666666666667,
#    0.050833333333333335,
#    0.14416666666666667,
#    0.003333333333333334,
#    0.1225,
#    -0.03416666666666666,
#    -0.0016666666666666774,
#    0.135,
#    0.11083333333333334,
#    -0.01750000000000001],
#   'sub-118': [-0.07916666666666666,
#    -0.23833333333333334,
#    -0.21583333333333332,
#    -0.1691666666666667,
#    -0.1325,
#    -0.14833333333333334,
#    0.02000000000000001,
#    -0.06999999999999999,
#    -0.10666666666666666,
#    -0.10333333333333333,
#    -0.04916666666666667,
#    -0.07833333333333332,
#    0.004166666666666673,
#    -0.03083333333333333,
#    0.0008333333333333387,
#    -0.007500000000000007,
#    0.014999999999999986,
#    -0.13916666666666666,
#    -0.14249999999999996,
#    -0.011666666666666653,
#    -0.041666666666666664,
#    0.05,
#    0.03416666666666668,
#    0.041666666666666664,
#    0.04416666666666666,
#    0.0675,
#    -0.017500000000000005,
#    -0.02416666666666668,
#    -0.09999999999999998,
#    -0.03166666666666666,
#    -0.019999999999999997,
#    0.03499999999999998,
#    -0.013333333333333332,
#    0.008333333333333345,
#    -0.09500000000000001,
#    0.05583333333333335,
#    0.038333333333333316,
#    0.003333333333333334,
#    0.0125,
#    0.030833333333333324,
#    0.045,
#    0.04416666666666669,
#    0.09833333333333333,
#    0.04416666666666666,
#    0.037500000000000006,
#    0.07083333333333333,
#    0.0825,
#    -0.011666666666666665,
#    0.05916666666666669,
#    -0.026666666666666665,
#    0.02166666666666668,
#    0.005833333333333315,
#    0.021666666666666654,
#    0.006666666666666696,
#    0.065,
#    -0.029166666666666674,
#    0.019166666666666665,
#    0.036666666666666646,
#    0.08416666666666665,
#    0.1625,
#    0.06166666666666666,
#    0.14416666666666664,
#    0.11166666666666666,
#    0.11916666666666667,
#    0.1433333333333333,
#    0.037500000000000006,
#    0.03166666666666667,
#    0.025833333333333326,
#    -0.08833333333333333,
#    -0.060833333333333336,
#    -0.08750000000000001,
#    -0.03583333333333336,
#    -0.06083333333333334,
#    -0.03],
#   'sub-111': [-0.027499999999999993,
#    0.04000000000000001,
#    0.07416666666666667,
#    0.07750000000000001,
#    0.04833333333333333,
#    0.010833333333333323,
#    -0.04666666666666667,
#    -0.135,
#    -0.065,
#    -0.1025,
#    -0.05000000000000001,
#    -0.10083333333333333,
#    -0.05916666666666666,
#    -0.08083333333333334,
#    -0.024166666666666677,
#    0.04666666666666666,
#    0.09166666666666666,
#    0.029999999999999992,
#    0.019999999999999976,
#    -0.04416666666666667,
#    -0.09583333333333333,
#    -0.03666666666666667,
#    -0.007499999999999996,
#    -0.054166666666666696,
#    -0.025000000000000015,
#    -0.09833333333333333,
#    -0.02416666666666667,
#    -0.0866666666666667,
#    0.010000000000000002,
#    -0.11,
#    0.0016666666666666705,
#    0.03749999999999999,
#    0.060000000000000005,
#    0.09583333333333333,
#    -0.05916666666666667,
#    -0.0050000000000000044,
#    0.009999999999999995,
#    0.11333333333333336,
#    0.05583333333333334,
#    0.041666666666666664,
#    -0.013333333333333334,
#    0.008333333333333328,
#    -0.005833333333333336,
#    0.025833333333333326,
#    -0.009166666666666656,
#    0.03833333333333334,
#    0.1691666666666667,
#    0.033333333333333305,
#    0.013333333333333357,
#    0.01083333333333334,
#    0.057499999999999996,
#    0.034166666666666665,
#    0.10833333333333332,
#    -0.012500000000000025,
#    0.06499999999999999,
#    0.01916666666666667,
#    -0.03583333333333334,
#    -0.05500000000000001,
#    0.07083333333333333,
#    0.14500000000000002,
#    0.20083333333333334,
#    0.04499999999999999,
#    0.09083333333333334,
#    0.08750000000000001,
#    0.10666666666666667,
#    0.16083333333333338,
#    0.10916666666666668,
#    0.0875,
#    0.08583333333333333,
#    0.055833333333333346,
#    -0.01333333333333335,
#    0.10500000000000001,
#    0.06583333333333333,
#    0.01666666666666666],
#   'sub-141': [-0.01916666666666665,
#    0.01166666666666668,
#    0.050000000000000024,
#    0.008333333333333328,
#    -0.05833333333333334,
#    0.025,
#    -0.010833333333333337,
#    0.13333333333333336,
#    -0.05416666666666668,
#    -0.0008333333333333318,
#    0.015,
#    -0.07916666666666668,
#    -0.05833333333333334,
#    -0.0225,
#    -0.06166666666666667,
#    0.021666666666666667,
#    -0.004166666666666659,
#    0.04083333333333334,
#    0.049166666666666664,
#    -0.0016666666666666843,
#    0.07666666666666667,
#    0.09333333333333331,
#    0.17333333333333334,
#    0.09333333333333334,
#    0.0991666666666667,
#    0.18416666666666667,
#    0.21833333333333332,
#    0.13333333333333336,
#    0.13583333333333336,
#    0.06999999999999998,
#    0.11666666666666667,
#    0.030000000000000002,
#    0.0049999999999999975,
#    0.015000000000000006,
#    0.10583333333333331,
#    0.0075000000000000015,
#    0.024166666666666677,
#    0.08166666666666668,
#    0.04583333333333334,
#    0.05750000000000001,
#    0.11416666666666667,
#    0.10999999999999999,
#    0.0016666666666666774,
#    0.0049999999999999906,
#    0.019166666666666672,
#    0.08666666666666666,
#    0.037500000000000006,
#    -0.008333333333333333,
#    0.12333333333333331,
#    0.006666666666666675,
#    0.07416666666666667,
#    0.06999999999999999,
#    0.0008333333333333248,
#    0.10250000000000001,
#    0.06916666666666668,
#    0.06416666666666666,
#    0.07916666666666666,
#    0.048333333333333346,
#    0.09916666666666665,
#    0.1125,
#    0.011666666666666662,
#    0.09333333333333332,
#    0.03833333333333333,
#    -0.028333333333333335,
#    0.02916666666666666,
#    0.0049999999999999906,
#    0.08583333333333333,
#    0.11333333333333333,
#    0.056666666666666664,
#    0.05000000000000002,
#    0.12166666666666667,
#    0.14916666666666667,
#    0.16750000000000004,
#    -0.012500000000000004],
#   'sub-103': [0.04083333333333332,
#    0.02416666666666667,
#    0.12333333333333335,
#    0.02833333333333333,
#    0.055,
#    0.02166666666666668,
#    0.029166666666666657,
#    0.026666666666666658,
#    0.013333333333333322,
#    0.05333333333333334,
#    -0.02416666666666667,
#    0.02083333333333335,
#    -0.045833333333333295,
#    -0.009999999999999988,
#    0.04416666666666665,
#    0.09250000000000001,
#    -0.011666666666666665,
#    -0.020833333333333325,
#    0.05416666666666668,
#    -0.035,
#    -0.05500000000000003,
#    -0.010000000000000002,
#    -0.018333333333333326,
#    -0.06166666666666667,
#    -0.019166666666666672,
#    -0.11583333333333332,
#    0.03083333333333333,
#    0.01666666666666667,
#    -0.0375,
#    -0.05083333333333332,
#    -0.009166666666666663,
#    -0.028333333333333332,
#    0.0225,
#    -0.06583333333333333,
#    -0.01333333333333333,
#    0.0024999999999999953,
#    0.055833333333333346,
#    -0.02666666666666667,
#    -0.10666666666666665,
#    0.015,
#    -0.05083333333333334,
#    -0.054166666666666655,
#    -0.07666666666666666,
#    -0.055000000000000014,
#    -0.09166666666666667,
#    -0.08916666666666667,
#    0.004166666666666666,
#    0.020000000000000004,
#    -0.1741666666666667,
#    -0.044999999999999984,
#    0.01583333333333333,
#    -0.03249999999999997,
#    -0.046666666666666703,
#    -0.050000000000000024,
#    -0.058333333333333307,
#    -0.049166666666666664,
#    -0.06666666666666667,
#    -0.011666666666666652,
#    -0.15249999999999997,
#    -0.08083333333333334,
#    -0.0025000000000000022,
#    -0.04916666666666667,
#    0.011666666666666672,
#    -0.05,
#    -0.05583333333333334,
#    -0.05833333333333334,
#    -0.019999999999999983,
#    -0.04333333333333334,
#    -0.07916666666666666,
#    -0.03499999999999998,
#    -0.0075,
#    -0.045000000000000005,
#    -0.14416666666666664,
#    -0.034166666666666665],
#   'sub-104': [-0.17333333333333334,
#    -0.061666666666666654,
#    -0.09,
#    -0.052500000000000005,
#    -0.19416666666666665,
#    -0.11333333333333334,
#    -0.1325,
#    -0.08583333333333334,
#    -0.13416666666666666,
#    -0.08833333333333337,
#    -0.13166666666666668,
#    -0.13333333333333333,
#    -0.20666666666666667,
#    -0.12000000000000001,
#    -0.16166666666666668,
#    -0.07750000000000001,
#    -0.13916666666666666,
#    0.0050000000000000044,
#    -0.01750000000000001,
#    -0.0725,
#    0.02333333333333333,
#    0.04166666666666666,
#    -0.049999999999999996,
#    -0.0016666666666666496,
#    0.005833333333333329,
#    0.015833333333333328,
#    -0.025000000000000015,
#    0.003333333333333341,
#    0.0325,
#    0.02083333333333334,
#    0.039166666666666655,
#    0.05833333333333332,
#    -0.025833333333333326,
#    0.054166666666666655,
#    0.08666666666666668,
#    0.027499999999999997,
#    0.0775,
#    0.05750000000000001,
#    0.01250000000000001,
#    0.044166666666666674,
#    0.021666666666666674,
#    0.03416666666666668,
#    0.05166666666666668,
#    -0.010833333333333332,
#    -0.0008333333333333179,
#    0.14250000000000002,
#    0.043333333333333335,
#    -0.04583333333333333,
#    0.0775,
#    0.055000000000000014,
#    0.08583333333333333,
#    0.09583333333333333,
#    0.010833333333333323,
#    -0.003333333333333334,
#    0.07750000000000001,
#    0.04333333333333333,
#    0.1316666666666667,
#    0.11000000000000001,
#    -0.04750000000000001,
#    0.004166666666666662,
#    0.011666666666666665,
#    0.05666666666666668,
#    0.06416666666666666,
#    0.032499999999999994,
#    -0.0016666666666666653,
#    -0.04166666666666668,
#    0.03416666666666667,
#    0.004999999999999996,
#    -0.03916666666666666,
#    -0.05083333333333334,
#    -0.049999999999999996,
#    0.06,
#    -0.025,
#    0.0725],
#   'sub-132': [0.030833333333333338,
#    -0.11916666666666667,
#    0.14,
#    0.04416666666666666,
#    0.09999999999999998,
#    0.0675,
#    0.16000000000000003,
#    0.08,
#    0.07333333333333333,
#    0.11416666666666667,
#    0.04583333333333334,
#    0.08916666666666666,
#    -0.0050000000000000044,
#    -0.010000000000000004,
#    0.08333333333333333,
#    -0.017500000000000005,
#    0.06250000000000001,
#    0.07333333333333332,
#    0.07833333333333332,
#    -0.040833333333333305,
#    -0.0008333333333333456,
#    0.0325,
#    -0.012500000000000004,
#    0.049166666666666664,
#    0.053333333333333344,
#    0.1325,
#    0.057499999999999996,
#    0.010833333333333292,
#    -0.017499999999999988,
#    0.13166666666666663,
#    -0.02416666666666669,
#    0.08083333333333331,
#    0.03166666666666666,
#    0.03249999999999996,
#    -0.019999999999999997,
#    0.15249999999999997,
#    0.04750000000000001,
#    0.07916666666666669,
#    -0.019166666666666665,
#    0.07166666666666668,
#    -0.07,
#    0.019999999999999997,
#    -0.042499999999999996,
#    0.09999999999999999,
#    0.07916666666666666,
#    -0.07333333333333333,
#    -0.01416666666666666,
#    0.06000000000000001,
#    0.01916666666666668,
#    0.11250000000000004,
#    0.06083333333333335,
#    0.009166666666666656,
#    0.11416666666666667,
#    0.04583333333333332,
#    -0.032499999999999994,
#    0.15250000000000002,
#    -0.016666666666666677,
#    0.039999999999999994,
#    0.03000000000000001,
#    0.11916666666666667,
#    0.01583333333333333,
#    0.045000000000000005,
#    0.12416666666666668,
#    0.020000000000000007,
#    0.04666666666666668,
#    0.10666666666666666,
#    0.044166666666666674,
#    0.08249999999999999,
#    -0.028333333333333335,
#    0.08333333333333334,
#    0.06833333333333333,
#    0.11416666666666667,
#    -0.03833333333333334,
#    0.11166666666666665],
#   'sub-119': [-0.25333333333333335,
#    -0.06250000000000003,
#    -0.10333333333333333,
#    -0.01833333333333334,
#    -0.13499999999999998,
#    -0.09166666666666666,
#    -0.1991666666666667,
#    -0.048333333333333325,
#    -0.2591666666666666,
#    -0.12083333333333332,
#    -0.21833333333333332,
#    -0.1608333333333333,
#    -0.30833333333333335,
#    -0.2625,
#    -0.3216666666666667,
#    -0.14666666666666664,
#    -0.24833333333333332,
#    -0.18250000000000005,
#    -0.2641666666666667,
#    -0.2366666666666667,
#    -0.28750000000000003,
#    -0.004999999999999963,
#    -0.014166666666666702,
#    0.10250000000000001,
#    0.02750000000000001,
#    0.08249999999999999,
#    0.10750000000000001,
#    0.17833333333333332,
#    0.18333333333333332,
#    0.23916666666666667,
#    0.1425,
#    0.25583333333333336,
#    0.22833333333333333,
#    0.1391666666666667,
#    0.26499999999999996,
#    0.21083333333333332,
#    0.235,
#    0.20666666666666667,
#    0.15833333333333333,
#    0.11916666666666666,
#    0.11250000000000002,
#    0.13416666666666666,
#    0.13916666666666666,
#    -0.09166666666666665,
#    0.031666666666666676,
#    0.03666666666666667,
#    -0.07166666666666667,
#    -0.2433333333333333,
#    -0.14500000000000002,
#    -0.019166666666666665,
#    -0.035,
#    -0.09833333333333333,
#    -0.08416666666666667,
#    -0.16249999999999998,
#    -0.03916666666666667,
#    -0.1075,
#    -0.09416666666666666,
#    -0.1325,
#    -0.19416666666666665,
#    -0.04083333333333332,
#    -0.23833333333333334,
#    -0.065,
#    -0.09916666666666667,
#    -0.040833333333333326,
#    0.004166666666666652,
#    0.030833333333333338,
#    0.135,
#    0.0875,
#    0.18333333333333335,
#    0.020000000000000004,
#    0.061666666666666654,
#    0.07250000000000001,
#    0.005833333333333322,
#    -0.018333333333333333],
#   'sub-125': [0.07750000000000001,
#    0.06666666666666667,
#    0.0825,
#    0.07416666666666667,
#    0.09166666666666667,
#    0.13333333333333333,
#    0.06916666666666668,
#    0.08083333333333333,
#    0.05,
#    0.08666666666666667,
#    0.029166666666666678,
#    -0.02750000000000001,
#    0.10583333333333333,
#    -0.009166666666666667,
#    -0.009999999999999995,
#    -0.0675,
#    0.095,
#    0.1383333333333333,
#    0.14666666666666667,
#    0.059166666666666645,
#    0.01333333333333334,
#    0.022499999999999992,
#    0.006666666666666668,
#    -0.023333333333333324,
#    0.11166666666666664,
#    0.02833333333333334,
#    -0.019166666666666665,
#    -0.10416666666666667,
#    0.006666666666666644,
#    -0.08166666666666667,
#    -0.05999999999999999,
#    -0.013333333333333343,
#    -0.1983333333333333,
#    -0.08499999999999999,
#    -0.03166666666666666,
#    -0.12250000000000001,
#    0.03333333333333334,
#    -0.14666666666666667,
#    -0.135,
#    -0.04833333333333334,
#    -0.15249999999999997,
#    -0.14500000000000002,
#    -0.10250000000000002,
#    -0.13333333333333336,
#    -0.135,
#    0.0016666666666666635,
#    -0.085,
#    0.035833333333333335,
#    -0.07916666666666666,
#    0.010833333333333323,
#    0.018333333333333344,
#    -0.07999999999999999,
#    -0.0675,
#    -0.15750000000000003,
#    -0.15166666666666667,
#    0.0275,
#    -0.035,
#    0.0033333333333333375,
#    -0.07249999999999998,
#    0.025833333333333337,
#    -0.01666666666666666,
#    -0.07916666666666666,
#    0.014166666666666668,
#    -0.04583333333333333,
#    -0.026666666666666665,
#    -0.10916666666666666,
#    -0.09083333333333332,
#    0.0775,
#    0.027500000000000007,
#    0.029999999999999992,
#    0.012499999999999997,
#    -0.0841666666666667,
#    -0.030000000000000006,
#    -0.04416666666666666],
#   'sub-106': [-0.13499999999999998,
#    0.030833333333333324,
#    0.007500000000000014,
#    -0.02083333333333334,
#    -0.014166666666666668,
#    0.08416666666666667,
#    0.03083333333333334,
#    0.035833333333333335,
#    -0.008333333333333338,
#    -0.11166666666666666,
#    -0.003333333333333327,
#    0.015833333333333328,
#    0.08,
#    -0.02583333333333334,
#    0.036666666666666674,
#    -0.07666666666666666,
#    0.03083333333333333,
#    0.05833333333333333,
#    -0.03333333333333333,
#    0.24333333333333337,
#    0.0275,
#    0.14166666666666664,
#    -0.10250000000000001,
#    0.07583333333333334,
#    -0.03833333333333333,
#    0.015000000000000001,
#    -0.019166666666666665,
#    0.1816666666666667,
#    0.10416666666666666,
#    0.1791666666666667,
#    0.019166666666666672,
#    0.19250000000000003,
#    -0.044166666666666674,
#    0.15333333333333332,
#    -0.023333333333333334,
#    0.10166666666666667,
#    0.009166666666666674,
#    0.17666666666666664,
#    -0.03,
#    0.03833333333333333,
#    0.008333333333333338,
#    -0.03499999999999999,
#    0.01833333333333334,
#    -0.023333333333333327,
#    0.06000000000000001,
#    -0.03916666666666667,
#    0.07166666666666668,
#    -0.058333333333333334,
#    -0.058333333333333334,
#    0.021666666666666695,
#    0.05500000000000001,
#    0.00916666666666667,
#    -0.11583333333333334,
#    -0.06249999999999999,
#    -0.06500000000000002,
#    -0.08499999999999999,
#    0.0325,
#    -0.06333333333333334,
#    0.017499999999999998,
#    -0.033333333333333326,
#    0.0025000000000000113,
#    -0.0041666666666666675,
#    0.012500000000000018,
#    0.01166666666666668,
#    0.08166666666666667,
#    -0.03583333333333334,
#    0.02,
#    0.04416666666666666,
#    0.05583333333333334,
#    0.05833333333333333,
#    0.038333333333333344,
#    0.08,
#    0.12916666666666668,
#    -0.03833333333333333],
#   'sub-102': [-0.10416666666666667,
#    0.02750000000000003,
#    -0.1,
#    -0.012499999999999997,
#    -0.045,
#    -0.09500000000000001,
#    -0.125,
#    -0.12666666666666665,
#    -0.1275,
#    -0.02916666666666667,
#    -0.05750000000000001,
#    -0.18333333333333332,
#    -0.12416666666666668,
#    -0.11749999999999998,
#    -0.15333333333333335,
#    -0.12166666666666667,
#    -0.09333333333333334,
#    -0.03916666666666667,
#    -0.019999999999999997,
#    -0.055833333333333346,
#    -0.09166666666666667,
#    -0.13833333333333334,
#    -0.19333333333333333,
#    -0.11583333333333334,
#    -0.11333333333333334,
#    -0.09666666666666668,
#    -0.11583333333333333,
#    -0.08083333333333333,
#    -0.125,
#    -0.14500000000000002,
#    -0.06499999999999999,
#    -0.12333333333333335,
#    -0.00666666666666667,
#    -0.037500000000000006,
#    -0.10166666666666668,
#    -0.06416666666666666,
#    -0.095,
#    -0.11499999999999999,
#    -0.03333333333333334,
#    -0.001666666666666667,
#    -0.09083333333333334,
#    -0.08166666666666669,
#    -0.025,
#    -0.037500000000000006,
#    -0.08916666666666666,
#    0.05333333333333334,
#    -0.009166666666666686,
#    0.008181818181818172,
#    -0.05363636363636365,
#    -0.07363636363636364,
#    -0.08545454545454546,
#    -0.019090909090909082,
#    -0.046363636363636364,
#    6.938893903907228e-18,
#    -0.04,
#    0.03727272727272728,
#    0.09454545454545454,
#    0.18,
#    0.09454545454545454,
#    0.17636363636363633,
#    0.11272727272727273,
#    0.04090909090909088,
#    0.13909090909090913,
#    0.11181818181818182,
#    0.11363636363636365,
#    0.15636363636363634,
#    0.08727272727272727,
#    0.1581818181818182,
#    0.05909090909090908,
#    0.1509090909090909,
#    0.12818181818181817,
#    0.08636363636363638,
#    0.07727272727272727,
#    0.04843353500623859],
#   'sub-105': [-0.06333333333333335,
#    -0.03583333333333332,
#    -0.11083333333333331,
#    -0.055,
#    -0.05083333333333335,
#    -0.12999999999999998,
#    -0.11416666666666668,
#    0.08916666666666667,
#    0.16416666666666668,
#    0.18583333333333335,
#    0.14749999999999996,
#    0.21166666666666667,
#    0.15166666666666667,
#    0.10833333333333334,
#    0.053333333333333316,
#    0.11333333333333334,
#    0.05666666666666667,
#    0.10333333333333333,
#    0.11500000000000003,
#    -6.938893903907228e-18,
#    0.05416666666666668,
#    0.07,
#    -0.029999999999999978,
#    0.06249999999999999,
#    0.10083333333333334,
#    0.052500000000000005,
#    0.1175,
#    0.10416666666666666,
#    0.09416666666666668,
#    0.1408333333333333,
#    0.12083333333333332,
#    0.14416666666666667,
#    0.1691666666666667,
#    0.10416666666666667,
#    0.1225,
#    0.16750000000000004,
#    0.16083333333333333,
#    0.15083333333333335,
#    0.14083333333333334,
#    0.21,
#    0.14083333333333334,
#    0.1875,
#    0.05833333333333333,
#    0.12166666666666665,
#    0.125,
#    0.075,
#    0.10250000000000001,
#    0.04583333333333333,
#    0.10083333333333333,
#    0.10083333333333334,
#    0.049166666666666664,
#    0.11083333333333334,
#    0.08333333333333336,
#    0.18583333333333332,
#    0.12166666666666667,
#    0.04083333333333332,
#    0.06,
#    0.046666666666666676,
#    0.07083333333333333,
#    0.025,
#    0.051666666666666666,
#    0.08666666666666664,
#    0.13000000000000003,
#    0.006666666666666661,
#    0.01666666666666667,
#    0.021666666666666674,
#    0.06916666666666668,
#    0.011666666666666669,
#    0.019999999999999993,
#    -0.013333333333333336,
#    0.005000000000000001,
#    -0.009999999999999988,
#    0.035,
#    0.05416666666666665],
#   'sub-137': [-0.0825,
#    -0.08666666666666666,
#    0.10166666666666668,
#    -0.08083333333333331,
#    0.08999999999999998,
#    -0.02666666666666667,
#    0.08499999999999999,
#    0.009999999999999974,
#    -0.1883333333333333,
#    0.040833333333333326,
#    -0.03666666666666667,
#    -0.04333333333333333,
#    -0.055000000000000014,
#    0.07583333333333334,
#    -0.055833333333333346,
#    -0.08583333333333333,
#    -0.016666666666666663,
#    -0.02083333333333335,
#    0.11583333333333333,
#    0.02166666666666667,
#    0.09166666666666669,
#    -0.01583333333333332,
#    0.01916666666666667,
#    -0.039166666666666676,
#    -0.03916666666666667,
#    -0.015000000000000003,
#    0.05333333333333333,
#    -0.03250000000000001,
#    -0.015833333333333345,
#    0.05250000000000001,
#    0.04583333333333333,
#    0.0725,
#    0.006666666666666666,
#    -0.021666666666666674,
#    -0.06833333333333333,
#    -0.02583333333333334,
#    0.01916666666666667,
#    0.042499999999999996,
#    -0.01499999999999999,
#    0.04916666666666667,
#    -0.05500000000000001,
#    -0.06083333333333334,
#    -0.06500000000000002,
#    -0.09666666666666668,
#    0.06583333333333334,
#    -0.05166666666666667,
#    0.10499999999999998,
#    -0.050833333333333335,
#    0.026666666666666665,
#    -0.0016666666666666635,
#    0.003333333333333334,
#    0.04249999999999998,
#    0.04333333333333333,
#    -0.0016666666666666655,
#    -0.08666666666666667,
#    0.004166666666666673,
#    0.02833333333333335,
#    0.027500000000000004,
#    0.039166666666666676,
#    0.03750000000000001,
#    -0.06916666666666665,
#    -0.10333333333333333,
#    0.0016666666666666774,
#    -0.062499999999999986,
#    -0.12416666666666668,
#    0.0016666666666666878,
#    0.027499999999999986,
#    0.02916666666666667,
#    0.025833333333333333,
#    -0.10083333333333333,
#    -0.057499999999999996,
#    -0.010833333333333334,
#    -0.012499999999999983,
#    -0.027499999999999997],
#   'sub-126': [0.04416666666666667,
#    0.02666666666666666,
#    0.10583333333333333,
#    0.009166666666666663,
#    0.14916666666666667,
#    -0.06,
#    -0.006666666666666675,
#    0.04083333333333333,
#    0.13083333333333336,
#    0.125,
#    0.07249999999999997,
#    0.15166666666666667,
#    -0.018333333333333313,
#    0.09083333333333332,
#    0.01750000000000001,
#    0.09999999999999998,
#    0.08333333333333333,
#    0.125,
#    0.12666666666666665,
#    0.23750000000000002,
#    0.16166666666666668,
#    0.25916666666666666,
#    0.21416666666666667,
#    0.315,
#    0.23916666666666667,
#    0.24999999999999997,
#    0.4083333333333333,
#    0.2975,
#    0.3441666666666667,
#    0.33916666666666667,
#    0.36583333333333334,
#    0.30333333333333334,
#    0.41333333333333333,
#    0.3966666666666666,
#    0.37083333333333335,
#    0.4358333333333334,
#    0.24916666666666673,
#    0.3266666666666667,
#    0.26166666666666666,
#    0.31666666666666665,
#    0.4158333333333333,
#    0.39249999999999996,
#    0.385,
#    0.34750000000000003,
#    0.38666666666666666,
#    0.28583333333333333,
#    0.38416666666666666,
#    0.2425,
#    0.3816666666666667,
#    0.23749999999999996,
#    0.27,
#    0.24416666666666664,
#    0.39250000000000007,
#    0.31666666666666665,
#    0.3058333333333333,
#    0.24083333333333334,
#    0.059166666666666666,
#    0.08083333333333333,
#    0.10250000000000002,
#    0.06666666666666665,
#    0.165,
#    0.09499999999999999,
#    0.052500000000000005,
#    0.04166666666666667,
#    0.08000000000000002,
#    0.008333333333333335,
#    0.13916666666666666,
#    0.029166666666666667,
#    0.11333333333333331,
#    0.021666666666666674,
#    0.0675,
#    -0.08666666666666666,
#    0.010833333333333337,
#    -0.0025000000000000074],
#   'sub-122': [0.04583333333333332,
#    0.11833333333333333,
#    0.07416666666666666,
#    0.051666666666666666,
#    0.13833333333333334,
#    0.12166666666666667,
#    0.05,
#    0.05666666666666667,
#    0.019166666666666637,
#    0.08916666666666667,
#    0.052500000000000005,
#    0.09833333333333333,
#    0.08333333333333333,
#    0.05083333333333333,
#    0.14666666666666667,
#    0.08416666666666667,
#    0.08583333333333333,
#    0.05416666666666667,
#    -0.03500000000000001,
#    -0.005000000000000008,
#    -0.07666666666666667,
#    -0.010000000000000009,
#    0.029166666666666678,
#    0.04833333333333334,
#    -0.043333333333333335,
#    -0.025,
#    -0.07416666666666666,
#    -0.014999999999999986,
#    -0.08166666666666667,
#    -0.05499999999999999,
#    0.0008333333333333318,
#    -0.007499999999999997,
#    0.007500000000000034,
#    0.030833333333333338,
#    -0.0008333333333333335,
#    -0.05416666666666669,
#    0.03916666666666668,
#    0.07416666666666666,
#    0.18250000000000002,
#    0.14,
#    0.2041666666666667,
#    0.11749999999999998,
#    0.15666666666666665,
#    0.18500000000000003,
#    0.17083333333333334,
#    0.12583333333333335,
#    0.14833333333333332,
#    0.16749999999999998,
#    0.13916666666666666,
#    0.07,
#    0.07500000000000001,
#    0.0975,
#    0.10583333333333333,
#    0.08083333333333335,
#    0.016666666666666666,
#    0.009166666666666665,
#    0.0008333333333333318,
#    0.08166666666666665,
#    0.08166666666666668,
#    0.035833333333333335,
#    0.011666666666666669,
#    0.10166666666666668,
#    0.09916666666666667,
#    0.037500000000000006,
#    0.037500000000000006,
#    0.049166666666666664,
#    -0.003333333333333327,
#    -0.023333333333333338,
#    0.07083333333333333,
#    0.04916666666666668,
#    -0.02083333333333333,
#    0.0325,
#    -0.01666666666666666,
#    -0.008333333333333338],
#   'sub-124': [-0.008333333333333331,
#    0.05499999999999999,
#    0.0050000000000000044,
#    -0.07,
#    0.013333333333333329,
#    -0.0008333333333333231,
#    0.0016666666666666496,
#    -0.11249999999999999,
#    0.027500000000000004,
#    -0.045000000000000005,
#    -0.03083333333333333,
#    -0.025833333333333333,
#    -0.0425,
#    -0.0225,
#    0.029166666666666664,
#    0.05,
#    -0.015,
#    0.0008333333333333248,
#    -0.021666666666666667,
#    -0.013333333333333336,
#    -0.0008333333333333352,
#    -0.013333333333333336,
#    0.040833333333333326,
#    0.1875,
#    0.07333333333333333,
#    0.15916666666666668,
#    0.07750000000000001,
#    0.09250000000000003,
#    0.13333333333333336,
#    0.06166666666666667,
#    0.09916666666666665,
#    0.13166666666666668,
#    0.0475,
#    0.05416666666666666,
#    0.13166666666666665,
#    0.14500000000000002,
#    0.04083333333333332,
#    0.10083333333333334,
#    0.05583333333333333,
#    0.08750000000000001,
#    0.06833333333333333,
#    -0.003333333333333334,
#    0.06916666666666667,
#    0.07,
#    0.05749999999999999,
#    0.11416666666666668,
#    0.03916666666666666,
#    0.06583333333333333,
#    0.1875,
#    0.09666666666666669,
#    0.027499999999999997,
#    0.12833333333333335,
#    0.16000000000000003,
#    0.15416666666666665,
#    0.08416666666666664,
# ...
#    0.07999999999999999,
#    -0.0008333333333333352,
#    0.008333333333333333,
#    -0.07833333333333334,
#    -0.010833333333333334,
#    -0.03666666666666668,
#    0.025833333333333333,
#    -0.03166666666666667,
#    0.025000000000000015,
#    -0.014999999999999994,
#    0.06333333333333332,
#    -0.0725,
#    -0.10500000000000001,
#    -0.006666666666666668,
#    0.0225],
#   'sub-128': [-0.09583333333333335,
#    -0.09,
#    0.1475,
#    0.00916666666666667,
#    0.03249999999999999,
#    -0.017500000000000016,
#    0.09916666666666667,
#    -0.031666666666666676,
#    0.07,
#    -0.005000000000000001,
#    0.04583333333333332,
#    0.030000000000000006,
#    0.005833333333333336,
#    -0.004166666666666666,
#    0.02916666666666667,
#    -0.0008333333333333248,
#    0.06916666666666668,
#    0.06333333333333334,
#    -0.007499999999999989,
#    0.12416666666666666,
#    0.1691666666666667,
#    -0.016666666666666663,
#    0.08916666666666664,
#    -0.02833333333333333,
#    0.03749999999999999,
#    0.04249999999999999,
#    0.11666666666666667,
#    0.10749999999999998,
#    -0.008333333333333345,
#    0.09666666666666666,
#    -0.0875,
#    -0.018333333333333326,
#    0.08083333333333333,
#    0.009166666666666663,
#    0.12000000000000001,
#    0.25166666666666665,
#    0.060000000000000005,
#    0.19083333333333338,
#    0.06416666666666665,
#    0.049999999999999996,
#    -0.07583333333333331,
#    0.028333333333333342,
#    0.14583333333333334,
#    0.03916666666666667,
#    -0.003333333333333341,
#    -0.09083333333333335,
#    -0.049999999999999996,
#    -0.09916666666666667,
#    -0.004166666666666674,
#    0.024999999999999994,
#    -0.003333333333333327,
#    -0.07583333333333334,
#    -0.02249999999999999,
#    -0.06416666666666666,
#    0.0475,
#    -0.13666666666666666,
#    -0.10583333333333333,
#    0.057499999999999996,
#    0.04583333333333334,
#    0.02916666666666667,
#    0.032499999999999994,
#    0.016666666666666677,
#    -0.11416666666666665,
#    0.03583333333333333,
#    0.05416666666666667,
#    -0.026666666666666672,
#    -0.03000000000000002,
#    0.22333333333333333,
#    0.030833333333333327,
#    -0.04833333333333333,
#    -0.03833333333333333,
#    0.03833333333333333,
#    0.023333333333333334,
#    0.11833333333333333],
#   'sub-139': [0.09166666666666667,
#    0.125,
#    0.07750000000000001,
#    0.045000000000000005,
#    0.11916666666666667,
#    0.125,
#    0.0625,
#    0.04,
#    -0.0008333333333333383,
#    0.07083333333333335,
#    0.07750000000000001,
#    0.08083333333333334,
#    0.01916666666666666,
#    0.05,
#    0.02666666666666667,
#    0.037500000000000006,
#    0.04666666666666666,
#    0.125,
#    0.023333333333333324,
#    0.08000000000000002,
#    0.12916666666666665,
#    0.057499999999999996,
#    0.043333333333333335,
#    0.025833333333333326,
#    0.075,
#    0.1325,
#    0.09916666666666667,
#    0.0775,
#    0.03333333333333334,
#    0.04333333333333333,
#    0.04083333333333334,
#    0.13083333333333333,
#    0.04833333333333335,
#    0.07666666666666667,
#    0.06083333333333332,
#    0.12833333333333333,
#    0.060833333333333336,
#    0.09,
#    0.13916666666666666,
#    0.024166666666666666,
#    0.0008333333333333335,
#    0.14166666666666666,
#    0.10083333333333332,
#    0.15,
#    0.060000000000000005,
#    0.17916666666666664,
#    0.10916666666666666,
#    0.12249999999999998,
#    0.10083333333333333,
#    0.04583333333333334,
#    0.06999999999999999,
#    0.13583333333333333,
#    0.11833333333333335,
#    0.11416666666666667,
#    0.11083333333333334,
#    0.14166666666666666,
#    0.17166666666666663,
#    0.15333333333333332,
#    0.1475,
#    0.11499999999999999,
#    0.13833333333333334,
#    0.12333333333333334,
#    0.10749999999999998,
#    0.10416666666666667,
#    0.08499999999999999,
#    0.12166666666666666,
#    0.08583333333333333,
#    0.14416666666666667,
#    0.11250000000000002,
#    0.15083333333333332,
#    0.07083333333333335,
#    0.08166666666666667,
#    0.08666666666666667,
#    0.11249999999999999],
#   'sub-133': [-0.0016666666666666705,
#    -0.06333333333333332,
#    -0.10083333333333333,
#    -0.015833333333333335,
#    -0.06416666666666668,
#    0.02249999999999999,
#    -0.02833333333333333,
#    -0.024166666666666677,
#    -0.03500000000000001,
#    -0.21166666666666667,
#    -0.024166666666666652,
#    -0.12916666666666668,
#    -0.10916666666666666,
#    -0.10750000000000001,
#    -0.06333333333333332,
#    -0.15166666666666664,
#    -0.03333333333333332,
#    -0.0058333333333333535,
#    -0.10416666666666666,
#    -0.13583333333333336,
#    -0.09416666666666665,
#    -0.04583333333333332,
#    -0.10166666666666667,
#    -0.1625,
#    -0.049166666666666664,
#    -0.11916666666666667,
#    -0.07333333333333333,
#    -0.11083333333333334,
#    -0.12833333333333333,
#    -0.010833333333333334,
#    -0.04166666666666667,
#    -0.034166666666666665,
#    -0.013333333333333319,
#    -0.11416666666666667,
#    0.054166666666666655,
#    0.06,
#    0.029166666666666674,
#    -0.04916666666666665,
#    -0.027500000000000004,
#    -0.07833333333333334,
#    -0.09916666666666665,
#    -0.03833333333333334,
#    -0.03666666666666668,
#    -0.15333333333333335,
#    0.021666666666666657,
#    -0.06916666666666667,
#    -0.08916666666666669,
#    0.013333333333333336,
#    -0.09999999999999999,
#    -0.023333333333333324,
#    -0.08999999999999998,
#    0.1025,
#    0.04416666666666669,
#    0.04833333333333334,
#    0.10500000000000001,
#    0.18666666666666665,
#    0.10416666666666666,
#    0.10166666666666664,
#    0.14166666666666666,
#    0.12333333333333334,
#    0.15083333333333332,
#    0.10583333333333336,
#    0.04916666666666668,
#    0.19,
#    0.2325,
#    0.19083333333333335,
#    0.16166666666666668,
#    0.10583333333333332,
#    0.17416666666666664,
#    0.09999999999999999,
#    0.13999999999999999,
#    0.10333333333333333,
#    0.03833333333333332,
#    0.10666666666666666],
#   'sub-113': [0.17416666666666666,
#    0.035000000000000024,
#    -0.005000000000000018,
#    0.027500000000000024,
#    -0.049166666666666685,
#    -0.07083333333333332,
#    -0.14833333333333334,
#    0.033333333333333326,
#    -0.07583333333333334,
#    0.09166666666666666,
#    -0.09916666666666668,
#    -0.0008333333333333318,
#    -0.046666666666666676,
#    -0.03333333333333331,
#    -0.05333333333333334,
#    -0.07999999999999999,
#    0.019166666666666665,
#    -0.07500000000000002,
#    -0.03500000000000002,
#    0.13,
#    0.15416666666666665,
#    0.16666666666666666,
#    0.22916666666666669,
#    0.29166666666666663,
#    0.19583333333333333,
#    0.16083333333333333,
#    0.19666666666666666,
#    0.23333333333333334,
#    0.12083333333333332,
#    0.1875,
#    0.25333333333333335,
#    0.21499999999999997,
#    0.09083333333333332,
#    0.21000000000000002,
#    0.09416666666666668,
#    -0.016666666666666653,
#    -0.01833333333333333,
#    0.06916666666666668,
#    0.03416666666666665,
#    -0.008333333333333326,
#    -0.08166666666666669,
#    0.046666666666666676,
#    -0.0008333333333333526,
#    0.05750000000000001,
#    -0.07416666666666666,
#    -0.07416666666666669,
#    -0.12749999999999997,
#    -0.08666666666666667,
#    -0.07999999999999999,
#    -0.19333333333333336,
#    -0.22416666666666668,
#    -0.05249999999999999,
#    0.00583333333333334,
#    -0.06416666666666668,
#    -0.043333333333333335,
#    0.0008333333333333248,
#    -0.01916666666666667,
#    -0.1716666666666667,
#    -0.1675,
#    -0.275,
#    -0.19249999999999998,
#    -0.24583333333333332,
#    0.0016666666666666496,
#    -0.12583333333333335,
#    -0.10166666666666663,
#    -0.2975,
#    0.04916666666666667,
#    -0.06666666666666667,
#    -0.058333333333333334,
#    -0.08166666666666668,
#    0.075,
#    0.10416666666666666,
#    0.08666666666666667,
#    0.13666666666666666],
#   'sub-117': [0.010833333333333334,
#    -0.11249999999999998,
#    -0.07250000000000001,
#    -0.019166666666666672,
#    -0.009166666666666667,
#    0.05583333333333333,
#    0.11916666666666667,
#    0.016666666666666663,
#    0.021666666666666674,
#    -0.02750000000000001,
#    -0.12,
#    -0.06916666666666665,
#    -0.039166666666666655,
#    -0.09999999999999998,
#    0.0050000000000000044,
#    -0.0075000000000000015,
#    0.009999999999999981,
#    -0.01083333333333333,
#    -0.0625,
#    3.469446951953614e-18,
#    0.02083333333333333,
#    0.06583333333333333,
#    0.046666666666666676,
#    0.03416666666666665,
#    -0.05250000000000002,
#    0.08083333333333331,
#    0.03833333333333332,
#    -0.039166666666666676,
#    -0.10250000000000001,
#    0.029999999999999992,
#    0.06,
#    0.014166666666666673,
#    -0.07416666666666666,
#    0.011666666666666676,
#    0.01083333333333334,
#    0.0075,
#    -0.029166666666666667,
#    0.030833333333333345,
#    0.02666666666666667,
#    0.0066666666666666645,
#    0.11750000000000001,
#    -0.004166666666666666,
#    0.08666666666666667,
#    -0.005833333333333336,
#    0.023333333333333338,
#    0.048333333333333346,
#    0.05916666666666667,
#    0.030000000000000006,
#    0.029166666666666695,
#    -0.035833333333333335,
#    -0.03666666666666669,
#    0.07416666666666666,
#    0.03000000000000001,
#    0.021666666666666674,
#    -0.10083333333333333,
#    0.01750000000000001,
#    0.02999999999999999,
#    -0.004166666666666666,
#    0.05,
#    0.04416666666666667,
#    0.004999999999999987,
#    0.10083333333333333,
#    0.11416666666666667,
#    -1.734723475976807e-18,
#    -0.018333333333333337,
#    0.0025000000000000057,
#    0.039166666666666676,
#    -0.006666666666666666,
#    0.07833333333333334,
#    0.03333333333333333,
#    0.01833333333333332,
#    -0.027500000000000007,
#    -0.029999999999999992,
#    -0.009999999999999995],
#   'sub-108': [-0.07083333333333333,
#    0.030833333333333327,
#    -0.004166666666666666,
#    0.02749999999999999,
#    -0.0016666666666666774,
#    -0.14250000000000002,
#    -0.06500000000000002,
#    -0.07833333333333334,
#    -0.15083333333333335,
#    -0.004999999999999992,
#    -0.0008333333333333179,
#    -0.0825,
#    -0.09833333333333334,
#    -0.035833333333333335,
#    -0.15250000000000002,
#    -0.035833333333333335,
#    -0.09666666666666665,
#    0.014999999999999996,
#    -0.12833333333333333,
#    -0.09166666666666669,
#    -0.15583333333333332,
#    -0.02333333333333334,
#    -0.05833333333333335,
#    -0.014166666666666664,
#    -0.12916666666666665,
#    -0.01833333333333333,
#    -0.07,
#    -0.1475,
#    -0.15916666666666668,
#    -0.0625,
#    -0.06916666666666667,
#    -0.09583333333333335,
#    -0.09583333333333333,
#    -0.09333333333333334,
#    -0.06666666666666667,
#    -0.19166666666666665,
#    -0.0625,
#    -0.14,
#    -0.010000000000000002,
#    -0.008333333333333318,
#    0.05083333333333333,
#    -0.04083333333333334,
#    0.035833333333333335,
#    -0.09416666666666665,
#    -0.010833333333333348,
#    -0.061666666666666675,
#    -0.095,
#    0.007500000000000007,
#    -0.023333333333333327,
#    -0.05249999999999999,
#    -0.01916666666666665,
#    -0.12666666666666668,
#    -0.07333333333333333,
#    0.058333333333333334,
#    -0.05,
#    -0.07166666666666666,
#    -0.13249999999999998,
#    -0.17916666666666667,
#    -0.10166666666666667,
#    0.010000000000000002,
#    -0.08666666666666666,
#    -0.09583333333333333,
#    0.030833333333333338,
#    -0.09416666666666668,
#    -0.08249999999999999,
#    -0.015833333333333335,
#    -0.10750000000000001,
#    0.04416666666666667,
#    -0.05749999999999998,
#    -0.014999999999999986,
#    -0.10416666666666666,
#    0.031666666666666676,
#    -0.09833333333333333,
#    0.04916666666666666],
#   'sub-130': [0.0041666666666666935,
#    0.09249999999999999,
#    0.07,
#    0.0525,
#    -0.10000000000000002,
#    -0.24416666666666662,
#    -0.25583333333333336,
#    -0.22333333333333333,
#    -0.07333333333333335,
#    -0.14416666666666667,
#    -0.07500000000000004,
#    -0.005833333333333322,
#    0.05,
#    0.059166666666666666,
#    -0.010833333333333323,
#    0.06499999999999999,
#    0.01833333333333335,
#    0.13083333333333333,
#    0.13999999999999999,
#    0.1525,
#    0.12083333333333335,
#    0.15083333333333332,
#    0.013333333333333336,
#    -0.08416666666666667,
#    -0.09249999999999997,
#    -0.05583333333333331,
#    -0.005833333333333343,
#    -0.12666666666666665,
#    -0.11583333333333332,
#    -0.11916666666666667,
#    -0.05916666666666665,
#    0.023333333333333345,
#    -0.09583333333333335,
#    -0.06333333333333334,
#    -0.039999999999999994,
#    0.1775,
#    0.06583333333333333,
#    -0.012500000000000011,
#    -0.02083333333333333,
#    0.02666666666666668,
#    0.03833333333333333,
#    -0.04916666666666667,
#    -0.06583333333333333,
#    -0.08166666666666665,
#    -0.08916666666666667,
#    -0.06333333333333334,
#    -0.08666666666666667,
#    -0.058333333333333334,
#    -0.011666666666666672,
#    -0.0625,
#    -0.12166666666666667,
#    -0.014999999999999994,
#    -0.08583333333333333,
#    -0.03,
#    -0.031666666666666676,
#    -0.0050000000000000044,
#    0.026666666666666658,
#    0.010833333333333327,
#    0.02833333333333334,
#    -0.0033333333333333305,
#    0.08250000000000002,
#    0.10500000000000001,
#    0.07333333333333332,
#    0.18166666666666664,
#    0.09583333333333333,
#    0.10999999999999999,
#    0.16333333333333339,
#    0.15249999999999997,
#    0.18000000000000005,
#    0.2,
#    0.039166666666666655,
#    0.0075000000000000205,
#    0.0733333333333333,
#    0.07916666666666666],
#   'sub-143': [0.053333333333333344,
#    0.030000000000000006,
#    -0.095,
#    0.07583333333333335,
#    -0.05750000000000001,
#    0.052500000000000005,
#    0.030833333333333327,
#    0.07916666666666668,
#    -0.052500000000000005,
#    -0.03833333333333331,
#    0.09000000000000002,
#    -0.011666666666666665,
#    0.04583333333333334,
#    -0.0225,
#    0.1075,
#    0.03666666666666666,
#    0.04000000000000001,
#    -0.04833333333333333,
#    -0.016666666666666663,
#    0.07166666666666666,
#    -0.06583333333333334,
#    0.038333333333333344,
#    -0.03416666666666667,
#    -0.03916666666666667,
#    0.028333333333333346,
#    0.043333333333333335,
#    -0.09166666666666667,
#    0.08249999999999999,
#    -0.039999999999999994,
#    0.02000000000000001,
#    0.014166666666666664,
#    0.05666666666666667,
#    -0.04499999999999999,
#    0.08,
#    0.06916666666666668,
#    0.08666666666666666,
#    0.04583333333333336,
#    0.0024999999999999927,
#    -0.01416666666666666,
#    -0.036666666666666674,
#    0.02333333333333333,
#    0.10750000000000001,
#    -0.04416666666666667,
#    -0.0275,
#    0.051666666666666666,
#    -0.10750000000000001,
#    -0.05666666666666667,
#    -0.05000000000000001,
#    -0.07583333333333334,
#    -0.018333333333333347,
#    -0.061666666666666675,
#    -0.10333333333333333,
#    0.07333333333333333,
#    0.014999999999999996,
#    0.0016666666666666635,
#    0.08750000000000001,
#    -0.006666666666666675,
#    0.024999999999999994,
#    0.06,
#    -0.0025000000000000022,
#    -0.04,
#    -0.03416666666666667,
#    0.01250000000000001,
#    -0.049999999999999996,
#    -0.0325,
#    -0.16333333333333333,
#    -0.065,
#    -0.012500000000000011,
#    -0.06333333333333337,
#    -0.01999999999999999,
#    -0.05,
#    -0.05000000000000002,
#    -0.037500000000000026,
#    0.004166666666666673],
#   'sub-109': [-0.032499999999999966,
#    0.007500000000000007,
#    -0.12583333333333335,
#    -0.12583333333333332,
#    -0.049166666666666664,
#    0.08666666666666667,
#    0.11083333333333335,
#    -0.0024999999999999875,
#    0.16749999999999998,
#    -0.007499999999999996,
#    0.03916666666666667,
#    -0.125,
#    0.06916666666666665,
#    -0.01583333333333333,
#    0.05333333333333329,
#    -0.010833333333333334,
#    -0.03666666666666667,
#    -0.14333333333333334,
#    0.059166666666666666,
#    0.10583333333333333,
#    0.2541666666666667,
#    0.13749999999999998,
#    0.21833333333333332,
#    0.085,
#    0.20083333333333336,
#    0.11499999999999999,
#    0.14916666666666664,
#    0.1975,
#    0.21666666666666665,
#    0.23083333333333333,
#    0.015833333333333338,
#    0.007499999999999993,
#    -0.11083333333333333,
#    -0.035833333333333335,
#    0.1741666666666667,
#    0.13333333333333333,
#    0.2125,
#    0.14166666666666666,
#    0.26583333333333337,
#    0.2316666666666667,
#    0.11166666666666666,
#    0.16666666666666669,
#    0.12833333333333333,
#    0.1766666666666667,
#    0.13416666666666666,
#    0.24833333333333335,
#    0.23666666666666664,
#    0.18083333333333332,
#    0.13499999999999998,
#    0.10416666666666669,
#    0.01500000000000001,
#    -0.085,
#    0.065,
#    0.0,
#    0.020833333333333332,
#    0.07166666666666666,
#    0.09416666666666666,
#    0.22999999999999998,
#    0.21416666666666664,
#    0.10749999999999998,
#    0.10916666666666669,
#    0.22916666666666663,
#    0.1283333333333333,
#    0.26750000000000007,
#    0.16833333333333333,
#    0.27749999999999997,
#    0.26000000000000006,
#    0.21083333333333337,
#    0.1675,
#    0.22083333333333335,
#    0.23249999999999993,
#    0.235,
#    0.26416666666666666,
#    0.11666666666666665]}}

# %%
# get ttest statistics
def get_t_stat_of_list(list):
    """
    take in a list of size 40 for each particpant for a particular tr and comparison
    and output the tvalue
    """
    n = len(list)
    mean = (sum(list) / n)
    sd = stdev(list)
    sem = (sd / math.sqrt(n))
    t_stat = (mean / sem)
    return t_stat

def get_ttest_stats_each_template_comparison(template_to_compare_to_pid_to_tr_diffs):
    template_to_compare_to_trTstats = {}
    for template_id in template_to_compare_to_pid_to_tr_diffs:
        for compare_name in template_to_compare_to_pid_to_tr_diffs[template_id]:
            # check that all participants have the same length of tr_diffs
            # while also getting list of diffs at each tr
            length_tr_list = []
            tr_num_to_list_of_diffs = {}
            for pid in template_to_compare_to_pid_to_tr_diffs[template_id][compare_name]:
                tr_diffs = template_to_compare_to_pid_to_tr_diffs[template_id][compare_name][pid]
                for index,diff in enumerate(tr_diffs):
                    if index not in tr_num_to_list_of_diffs:
                        tr_num_to_list_of_diffs[index] = []
                    tr_num_to_list_of_diffs[index].append(diff)
                length_tr_list.append(len(tr_diffs))
            length_tr_list = np.array(length_tr_list)
            if not np.all(length_tr_list[0] == length_tr_list):
                pdb.set_trace()
                print("Error: not all the same length_tr_lists")
                return
            # now go through each tr index, and get a ttest
            # make sure that we have 40 participants in each tr num
            # and make sure we don't have nan
            for tr_num in tr_num_to_list_of_diffs:
                if len(tr_num_to_list_of_diffs[tr_num]) != 40 or np.isnan(sum(tr_num_to_list_of_diffs[tr_num])):
                    print(tr_num_to_list_of_diffs[tr_num])
                    pdb.set_trace()
                    print("Error: missing participant or nan")
                    return

            tr_Tstats = [get_t_stat_of_list(tr_num_to_list_of_diffs[tr_num]) for tr_num in range(0,len(tr_num_to_list_of_diffs.keys()))]
            if template_id not in template_to_compare_to_trTstats:
                template_to_compare_to_trTstats[template_id] = {}
            template_to_compare_to_trTstats[template_id][compare_name] = tr_Tstats
    return template_to_compare_to_trTstats
template_to_compare_to_trTstats = get_ttest_stats_each_template_comparison(template_to_compare_to_pid_to_tr_diffs)

# %% [markdown]
# # get 3 by 3 fingerprint plot for representative searchlight in cluster

# %%
def get_9fingerprint_plots(template_to_pid_to_cond_to_matrix):
    matching_id_labels_each_tr = []
    for i in range(0,17):
        matching_id_labels_each_tr.append(0)
    for i in range(17,23):
        matching_id_labels_each_tr.append(1)
    for i in range(23,34):
        matching_id_labels_each_tr.append(2)
    for i in range(34,50):
        matching_id_labels_each_tr.append(3)
    for i in range(50,66):
        matching_id_labels_each_tr.append(4)
    for i in range(66,74):
        matching_id_labels_each_tr.append(5)
    x_list_apply_to2 = []
    x_list_apply_to3or4 = []
    condition_list_apply_to2 = [palette[0] for i in range(440)] + [palette[1] for i in range(440)] + [palette[2] for i in range(440)] + [palette[3] for i in range(440)]
    condition_list_apply_to3or4 = [palette[0] for i in range(640)] + [palette[1] for i in range(640)] + [palette[2] for i in range(640)] + [palette[3] for i in range(640)]
    # 0_0
    plot_0_0 = []
    template_id = 2
    apply_to_id = 2
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_0_0 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
          #  import pdb
           # pdb.set_trace()
            x_list_apply_to2 += [i for i in range(11)]

    # 0_1
    plot_0_1 = []
    template_id = 3
    apply_to_id = 2
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_0_1 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    # 0_2
    plot_0_2 = []
    template_id = 4
    apply_to_id = 2
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_0_2 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    # 1_0
    plot_1_0 = []
    template_id = 2
    apply_to_id = 3
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_1_0 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            x_list_apply_to3or4 += [i for i in range(16)]
    
    # 1_1
    plot_1_1 = []
    template_id = 3
    apply_to_id = 3
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_1_1 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    # 1_2
    plot_1_2 = []
    template_id = 4
    apply_to_id = 3
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_1_2 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    # 2_0
    plot_2_0 = []
    template_id = 2
    apply_to_id = 4
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_2_0 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    # 2_1
    plot_2_1 = []
    template_id = 3
    apply_to_id = 4
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_2_1 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    
    # 2_2
    plot_2_2 = []
    template_id = 4
    apply_to_id = 4
    for condition_index, condition in enumerate(comparison_groups4):
        for pid in template_to_pid_to_cond_to_matrix[template_id]:
            avg_across_weddings = np.nanmean(template_to_pid_to_cond_to_matrix[template_id][pid][condition], axis = 0).tolist()
            plot_2_2 += (np.array(avg_across_weddings)[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
    return plot_0_0, plot_0_1, plot_0_2, plot_1_0, plot_1_1, plot_1_2, plot_2_0, plot_2_1, plot_2_2, x_list_apply_to2, x_list_apply_to3or4, condition_list_apply_to2, condition_list_apply_to3or4
plot_0_0, plot_0_1, plot_0_2, plot_1_0, plot_1_1, plot_1_2, plot_2_0, plot_2_1, plot_2_2, x_list_apply_to2, x_list_apply_to3or4, condition_list_apply_to2, condition_list_apply_to3or4 = get_9fingerprint_plots(template_to_pid_to_cond_to_matrix)

# %%
plt.rcParams["figure.figsize"] = [20, 20]
plt.rcParams["font.size"] = 15
plt.rcParams["figure.autolayout"] = True
f, axes = plt.subplots(3, 3)
for i in range(3):
    for j in range(3):
        axes[i,j].set(xlabel='TR', ylabel='neural similarity')
linewidth=4
df_apply_to_2 = pd.DataFrame(dict(plot0_0 = plot_0_0, 
                       plot0_1= plot_0_1,
                       plot0_2 = plot_0_2, 
                        x_list_apply_to2 = x_list_apply_to2,
                         condition_list_apply_to2 = condition_list_apply_to2 ))
df = pd.DataFrame(dict(
                       plot1_0= plot_1_0,
                       plot1_1 = plot_1_1, 
                       plot1_2= plot_1_2,
                       plot2_0 = plot_2_0, 
                       plot2_1= plot_2_1,
                       plot2_2 = plot_2_2, 
                        x_list_apply_to3or4 = x_list_apply_to3or4,
                         condition_list_apply_to3or4 = condition_list_apply_to3or4 ))
# apply to 2
sns.lineplot(data = df_apply_to_2, x = 'x_list_apply_to2', y='plot0_0', hue = condition_list_apply_to2, ax=axes[0,0],\
             palette=palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df_apply_to_2, y="plot0_1", x = 'x_list_apply_to2', hue = condition_list_apply_to2 , ax=axes[0,1], \
              palette= palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df_apply_to_2, y='plot0_2', x = 'x_list_apply_to2', hue = condition_list_apply_to2, ax=axes[0,2],\
             palette=palette, legend = False, linewidth = linewidth)


# apply to 2 or 3
sns.lineplot(data = df, y="plot1_0", x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4 , ax=axes[1,0], \
              palette= palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot1_1', x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4, ax=axes[1,1],\
             palette=palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot1_2", x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4 , ax=axes[1,2], \
              palette= palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot2_0', x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4, ax=axes[2,0],\
             palette=palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot2_1", x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4 , ax=axes[2,1], \
              palette= palette, legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot2_2', x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4, ax=axes[2,2],\
             palette=palette, legend = False, linewidth = linewidth)
plt.show()

# %% [markdown]
# # get 3 by 3 differences plot for representative searchlight

# %%
def get_9differences_plots(template_to_compare_to_pid_to_tr_diffs):
    matching_id_labels_each_tr = []
    for i in range(0,17):
        matching_id_labels_each_tr.append(0)
    for i in range(17,23):
        matching_id_labels_each_tr.append(1)
    for i in range(23,34):
        matching_id_labels_each_tr.append(2)
    for i in range(34,50):
        matching_id_labels_each_tr.append(3)
    for i in range(50,66):
        matching_id_labels_each_tr.append(4)
    for i in range(66,74):
        matching_id_labels_each_tr.append(5)
    x_list_apply_to2 = []
    x_list_apply_to3or4 = []
    condition_list_apply_to2 = [all6_differences_labels[0] for i in range(440)] + \
    [all6_differences_labels[1] for i in range(440)] + \
    [all6_differences_labels[2] for i in range(440)] + [all6_differences_labels[3] for i in range(440)] + \
        [all6_differences_labels[4] for i in range(440)] + \
    [all6_differences_labels[5] for i in range(440)]
        
    condition_list_apply_to3or4 = [all6_differences_labels[0] for i in range(640)] + \
    [all6_differences_labels[1] for i in range(640)] + [all6_differences_labels[2] for i in range(640)] +\
    [all6_differences_labels[3] for i in range(640)] + [all6_differences_labels[4] for i in range(640)] + \
    [all6_differences_labels[5] for i in range(640)] 
    plot_0_0 = []
    template_id = 2
    apply_to_id = 2
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_0_0 += diffs_this_ritual
            x_list_apply_to2 += [i for i in range(11)]

    # 0_1
    plot_0_1 = []
    template_id = 3
    apply_to_id = 2
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_0_1 += diffs_this_ritual

    # 0_2
    plot_0_2 = []
    template_id = 4
    apply_to_id = 2
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_0_2 += diffs_this_ritual
    # 1_0
    plot_1_0 = []
    template_id = 2
    apply_to_id = 3
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_1_0 += diffs_this_ritual
            x_list_apply_to3or4 += [i for i in range(16)]
    
    # 1_1
    plot_1_1 = []
    template_id = 3
    apply_to_id = 3
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_1_1 += diffs_this_ritual
    # 1_2
    plot_1_2 = []
    template_id = 4
    apply_to_id = 3
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_1_2 += diffs_this_ritual
    # 2_0
    plot_2_0 = []
    template_id = 2
    apply_to_id = 4
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_2_0 += diffs_this_ritual
    # 2_1
    plot_2_1 = []
    template_id = 3
    apply_to_id = 4
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_2_1 += diffs_this_ritual
    # 2_2
    plot_2_2 = []
    template_id = 4
    apply_to_id = 4
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        for pid in template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference]:
            diffs_all_trs = np.array(template_to_compare_to_pid_to_tr_diffs[template_id][comparison_difference][pid])
            diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
            plot_2_2 += diffs_this_ritual
    return plot_0_0, plot_0_1, plot_0_2, plot_1_0, plot_1_1, plot_1_2, plot_2_0, plot_2_1, plot_2_2, x_list_apply_to2, x_list_apply_to3or4, condition_list_apply_to2, condition_list_apply_to3or4
plot_0_0, plot_0_1, plot_0_2, plot_1_0, plot_1_1, plot_1_2, plot_2_0, plot_2_1, plot_2_2, x_list_apply_to2, x_list_apply_to3or4, condition_list_apply_to2, condition_list_apply_to3or4 = get_9differences_plots(template_to_compare_to_pid_to_tr_diffs)

# %%
plt.rcParams["figure.figsize"] = [20, 20]
plt.rcParams['figure.dpi'] = 1000
plt.rcParams["font.size"] = 15
plt.rcParams["figure.autolayout"] = True
sns.color_palette(palette='prism')
f, axes = plt.subplots(3, 3)
for i in range(3):
    for j in range(3):
        axes[i,j].set(xlabel='TR', ylabel='difference')
linewidth=40
df_apply_to_2 = pd.DataFrame(dict(plot0_0 = plot_0_0, 
                       plot0_1= plot_0_1,
                       plot0_2 = plot_0_2, 
                        x_list_apply_to2 = x_list_apply_to2,
                         condition_list_apply_to2 = condition_list_apply_to2 ))
df = pd.DataFrame(dict(
                       plot1_0= plot_1_0,
                       plot1_1 = plot_1_1, 
                       plot1_2= plot_1_2,
                       plot2_0 = plot_2_0, 
                       plot2_1= plot_2_1,
                       plot2_2 = plot_2_2, 
                        x_list_apply_to3or4 = x_list_apply_to3or4,
                         condition_list_apply_to3or4 = condition_list_apply_to3or4 ))
# apply to 2
sns.lineplot(data = df_apply_to_2, x = 'x_list_apply_to2', y='plot0_0', hue = condition_list_apply_to2, ax=axes[0,0],\
             legend = False, linewidth = linewidth)
sns.lineplot(data = df_apply_to_2, y="plot0_1", x = 'x_list_apply_to2', hue = condition_list_apply_to2 , ax=axes[0,1], \
            legend = False, linewidth = linewidth)
g = sns.lineplot(data = df_apply_to_2, y='plot0_2', x = 'x_list_apply_to2', hue = condition_list_apply_to2, ax=axes[0,2],\
              legend = True, linewidth = linewidth)
g.legend(loc='center left', bbox_to_anchor=(1, 0.5))


# apply to 2 or 3
sns.lineplot(data = df, y="plot1_0", x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4 , ax=axes[1,0], \
                legend = False,linewidth = linewidth)
sns.lineplot(data = df, y='plot1_1', x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4, ax=axes[1,1],\
            legend = False,linewidth = linewidth)
sns.lineplot(data = df, y="plot1_2", x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4 , ax=axes[1,2], \
              legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot2_0', x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4, ax=axes[2,0],\
           legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot2_1", x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4 , ax=axes[2,1], \
              legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot2_2', x = 'x_list_apply_to3or4', hue = condition_list_apply_to3or4, ax=axes[2,2],\
            legend = False, linewidth = linewidth)

plt.show()

# %% [markdown]
# # get 3 by 3 ttest statistics plots for representative searchlight

# %%
plt.rcParams["figure.autolayout"] = True
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["font.size"] = 15
sns.color_palette(palette='winter')

f, axes = plt.subplots(3, 3)
for i in range(3):
    for j in range(3):
        axes[i,j].set(xlabel='TR', ylabel='ttest statistic')
linewidth=4
TR_len = 10
num_Ss = 1
num_points_each_condition_per_grid = TR_len * num_Ss
palette= [x for x in range(6)]
x_list_init = [i for i in range(TR_len)]
x_list = []
Ss_id_list = []
for condition in palette:
    for TR_num in range(TR_len):
        for Ss_id in range(num_Ss):
            x_list.append(TR_num)
            Ss_id_list.append(Ss_id)

condition_list = []
for x in range(6):
    condition_list += [str(x + 1) for i in range(TR_len * num_Ss)] 
uniform_lb = -0.05
uniform_ub = 0.05
means6 =  [0.6, 1.6,1.8,1.4,2, 0.3]
blue_mean = -0.001
red_mean = -0.002
yellow_mean = 0.001
purple_mean = 0.002
yellow_purple_mean = 0.001
plot0_1 = []
plot0_2 = []
plot1_0 = []
plot1_1 = []
plot1_2 = []
plot2_0 = []
plot2_1 = []
plot2_2 = []

for i in range(6):
    print(i, means6)
    plot0_1 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot0_2 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot1_0 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot1_1 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot1_2 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot2_0 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot2_1 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]
    plot2_2 += [means6[i] + random.uniform(uniform_lb, uniform_ub) for tr in range(num_points_each_condition_per_grid)]


df = pd.DataFrame(dict(plot0_0 = plot0_0, 
                       plot0_1= plot0_1,
                       plot0_2 = plot0_2, 
                       plot1_0= plot1_0,
                       plot1_1 = plot1_1, 
                       plot1_2= plot1_2,
                       plot2_0 = plot2_0, 
                       plot2_1= plot2_1,
                       plot2_2 = plot2_2, 
                        x_list = x_list,
                         condition_list = condition_list ))
sns.lineplot(data = df, x = 'x_list', y='plot0_0', hue = condition_list, ax=axes[0,0],\
             palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot0_1", x = 'x_list', hue = condition_list , ax=axes[0,1], \
              palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot0_2', x = 'x_list', hue = condition_list, ax=axes[0,2],\
             palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot1_0", x = 'x_list', hue = condition_list , ax=axes[1,0], \
              palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot1_1', x = 'x_list', hue = condition_list, ax=axes[1,1],\
             palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot1_2", x = 'x_list', hue = condition_list , ax=axes[1,2], \
              palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot2_0', x = 'x_list', hue = condition_list, ax=axes[2,0],\
             palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y="plot2_1", x = 'x_list', hue = condition_list , ax=axes[2,1], \
              palette= 'winter', legend = False, linewidth = linewidth)
sns.lineplot(data = df, y='plot2_2', x = 'x_list', hue = condition_list, ax=axes[2,2],\
             palette='winter', legend = False, linewidth = linewidth)

plt.show()

# %%
def get_9ttestplots(template_to_compare_to_trTstats):
    matching_id_labels_each_tr = []
    for i in range(0,17):
        matching_id_labels_each_tr.append(0)
    for i in range(17,23):
        matching_id_labels_each_tr.append(1)
    for i in range(23,34):
        matching_id_labels_each_tr.append(2)
    for i in range(34,50):
        matching_id_labels_each_tr.append(3)
    for i in range(50,66):
        matching_id_labels_each_tr.append(4)
    for i in range(66,74):
        matching_id_labels_each_tr.append(5)
    x_list_apply_to2 = []
    x_list_apply_to3or4 = []
    condition_list_apply_to2 = [all6_differences_labels[0] for i in range(440)] + \
    [all6_differences_labels[1] for i in range(440)] + \
    [all6_differences_labels[2] for i in range(440)] + [all6_differences_labels[3] for i in range(440)] + \
        [all6_differences_labels[4] for i in range(440)] + \
    [all6_differences_labels[5] for i in range(440)]
        
    condition_list_apply_to3or4 = [all6_differences_labels[0] for i in range(640)] + \
    [all6_differences_labels[1] for i in range(640)] + [all6_differences_labels[2] for i in range(640)] +\
    [all6_differences_labels[3] for i in range(640)] + [all6_differences_labels[4] for i in range(640)] + \
    [all6_differences_labels[5] for i in range(640)] 
    plot_0_0 = []
    template_id = 2
    apply_to_id = 2
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_0_0 += diffs_this_ritual
        x_list_apply_to2 += [i for i in range(11)]

    # 0_1
    plot_0_1 = []
    template_id = 3
    apply_to_id = 2
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_0_1 += diffs_this_ritual

    # 0_2
    plot_0_2 = []
    template_id = 4
    apply_to_id = 2
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_0_2 += diffs_this_ritual
    # 1_0
    plot_1_0 = []
    template_id = 2
    apply_to_id = 3
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_1_0 += diffs_this_ritual
        x_list_apply_to3or4 += [i for i in range(16)]
    
    # 1_1
    plot_1_1 = []
    template_id = 3
    apply_to_id = 3
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_1_1 += diffs_this_ritual
    # 1_2
    plot_1_2 = []
    template_id = 4
    apply_to_id = 3
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_1_2 += diffs_this_ritual
    # 2_0
    plot_2_0 = []
    template_id = 2
    apply_to_id = 4
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_2_0 += diffs_this_ritual
    # 2_1
    plot_2_1 = []
    template_id = 3
    apply_to_id = 4
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_2_1 += diffs_this_ritual
    # 2_2
    plot_2_2 = []
    template_id = 4
    apply_to_id = 4
    for c_index, comparison_difference in enumerate(all_comparison_differences6):
        diffs_all_trs = np.array(template_to_compare_to_trTstats[template_id][comparison_difference])
        diffs_this_ritual = (diffs_all_trs[np.array(matching_id_labels_each_tr) == apply_to_id]).tolist()
        plot_2_2 += diffs_this_ritual
    return plot_0_0, plot_0_1, plot_0_2, plot_1_0, plot_1_1, plot_1_2, plot_2_0, plot_2_1, plot_2_2, x_list_apply_to2, x_list_apply_to3or4, condition_list_apply_to2, condition_list_apply_to3or4
plot_0_0, plot_0_1, plot_0_2, plot_1_0, plot_1_1, plot_1_2, plot_2_0, plot_2_1, plot_2_2, x_list_apply_to2, x_list_apply_to3or4, condition_list_apply_to2, condition_list_apply_to3or4 = get_9ttestplots(template_to_compare_to_trTstats)
